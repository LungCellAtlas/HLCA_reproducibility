# %% [markdown]
# ## Gene names processing

# %% [markdown]
# In this notebook we are digesting idtrack's output. We take the dictionaries and create a table of genes-ensembl pairs to determine what the final gene name will be. In the process we also find repeated gene names that will be merged, per dataset.

# %% [markdown]
# __author__ = "Ciro Ramírez-Suástegui"
#
# __copyright__ = "Copyright 2022-11-09, Helmholtz Zentrum Muenchen"
#
# __license__ = "GPL"
#
# __version__ = "0.0.9"
#
# __email__ = "ciro.suastegui@helmholtz-muenchen.de, ksuasteguic@gmail.com"
#
# __status__ = "Prototype"

# %% [markdown]
# #### Structure

# %% [markdown]
# * [Global variables and paths](#bullet1)
# * [Loading data](#bullet2)
# * [Pre-processing](#bullet3)
# * [Main](#bullet4)
# * [Conclusions](#bullet5)
# * [Save](#bullet6)

# %% [markdown]
# ### Environment setup

# %%
# %load_ext autoreload
# %autoreload 2
import importlib

spam_spec = importlib.util.find_spec("lab_black")
if spam_spec is not None:
    # %load_ext lab_black

# %%
# basic modules
import warnings, os, re
import time, sys

warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.simplefilter(action="ignore", category=UserWarning)

# %%
# in-house/developing modules
# tools modules
import scanpy as sc
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import itertools
from collections import Counter
from tqdm import tqdm
import pickle

# %%
sc.logging.print_versions()
# Out:
# -----
# anndata     0.8.0
# scanpy      1.9.1
# -----
# 7b32b9a39ad70713acde__mypyc NA
# PIL                         9.2.0
# autoreload                  NA
# backcall                    0.2.0
# beta_ufunc                  NA
# binom_ufunc                 NA
# black                       22.6.0
# blib2to3                    NA
# cffi                        1.15.1
# click                       8.1.3
# cycler                      0.10.0
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.6.3
# decorator                   5.1.1
# defusedxml                  0.7.1
# entrypoints                 0.4
# h5py                        3.7.0
# igraph                      0.9.11
# ipykernel                   6.16.0
# ipython_genutils            0.2.0
# jedi                        0.18.1
# joblib                      1.1.0
# jupyter_server              1.21.0
# kiwisolver                  1.4.4
# lab_black                   NA
# leidenalg                   0.8.10
# llvmlite                    0.39.0
# matplotlib                  3.5.2
# mpl_toolkits                NA
# mypy_extensions             NA
# natsort                     8.1.0
# nbinom_ufunc                NA
# numba                       0.56.0
# numpy                       1.21.6
# packaging                   21.3
# pandas                      1.3.5
# parso                       0.8.3
# pathspec                    0.9.0
# pexpect                     4.8.0
# pickleshare                 0.7.5
# pkg_resources               NA
# platformdirs                2.5.2
# prompt_toolkit              3.0.31
# psutil                      5.9.2
# ptyprocess                  0.7.0
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.8.0
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.13.0
# pyparsing                   3.0.9
# pytz                        2022.1
# scipy                       1.7.3
# session_info                1.0.0
# setuptools                  65.5.0
# six                         1.16.0
# sklearn                     1.0.2
# storemagic                  NA
# texttable                   1.6.4
# threadpoolctl               3.1.0
# tomli                       2.0.1
# tornado                     6.2
# tqdm                        4.64.0
# traitlets                   5.4.0
# typed_ast                   1.5.4
# typing_extensions           NA
# wcwidth                     0.2.5
# zipp                        NA
# zmq                         24.0.1
# -----
# IPython             7.34.0
# jupyter_client      7.4.2
# jupyter_core        4.11.1
# jupyterlab          3.4.4
# notebook            6.5.1
# -----
# Python 3.7.13 (default, Mar 29 2022, 02:18:16) [GCC 7.5.0]
# Linux-3.10.0-1160.25.1.el7.x86_64-x86_64-with-centos-7.9.2009-Core
# -----
# Session information updated at 2022-11-15 16:43

# %%
print("Environment:", re.sub(".os.py", "", os.__file__))
parentpath = lambda _path, n: os.sep.join(_path.split(os.sep)[:-n])
print("Working at:", re.sub(parentpath(os.getcwd(), 2), "", os.getcwd()))
# Out:
# Environment: /home/icb/ciro.suastegui/miniconda3/envs/HLCA_basic/lib/python3.7
# Working at: /notebooks/3_atlas_extension

# %%
def make_symbol(x):
    return re.sub(
        "^ENSG[0-9]{10,}\.[0-9]{1,}_|_ENSG[0-9]{10,}",  # "ENSG.*_|_ENSG[0-9]{10,}",
        "",
        re.sub(  # some artifacts from idtrack returns the mapping structure
            ".*\n",
            "",
            re.sub(  # which contains several names
                ".* {1,}",
                "",
                re.sub(
                    "\nName.*",
                    "",
                    x,
                ),
            ),
        ),
    )

# %% [markdown]
# ### Global variables and paths <a class="anchor" id="bullet1"></a>

# %%
feats_dir = "../../data/HLCA_extended/extension_datasets/features/"
feats_inp = (
    "../../data/HLCA_extended/extension_datasets/features/all_update-with-core.pk"
)
adata_split = {
    "HLCA": {
        "study": [
            "Nawijn_2021_HLCA",
            "Barbry_Leroy_2020_HLCA",
            "Meyer_2019_HLCA",
            "Banovich_Kropski_2020_HLCA",
            "Seibold_2020_HLCA",
            "Jain_Misharin_2021_HLCA",
            "Teichmann_Meyer_2019_HLCA",
            "Misharin_2021_HLCA",
            "Lafyatis_Rojas_2019_HLCA",
            "Krasnow_2020_HLCA",
            "Misharin_Budinger_2018_HLCA",
        ]
    }
}

# %% [markdown]
# ### Loading data <a class="anchor" id="bullet2"></a>

# %%
results_core = pd.read_pickle(
    "/lustre/groups/ml01/workspace/kemal.inecik/idtrack_temp/results_for_hlca_core_only_HGNC Symbol_20221110-094335.pk"
)
results_idtrack = pd.read_pickle(
    "/lustre/groups/ml01/workspace/kemal.inecik/idtrack_temp/results_for_hlca_datasets_HGNC Symbol_20221101-175029.pk"
)

# %%
results_core.keys()
results_core["HLCA_txt"][:3]
# Out:
# dict_keys(['HLCA_txt'])
# [{'target_id': ['TSPAN6'],
#   'last_node': [('ENSG00000000003.15', 'TSPAN6')],
#   'final_database': 'HGNC Symbol',
#   'graph_id': 'TSPAN6',
#   'query_id': 'TSPAN6',
#   'no_corresponding': False,
#   'no_conversion': False,
#   'no_target': False},
#  {'target_id': ['TNMD'],
#   'last_node': [('ENSG00000000005.6', 'TNMD')],
#   'final_database': 'HGNC Symbol',
#   'graph_id': 'TNMD',
#   'query_id': 'TNMD',
#   'no_corresponding': False,
#   'no_conversion': False,
#   'no_target': False},
#  {'target_id': ['DPM1'],
#   'last_node': [('ENSG00000000419.14', 'DPM1')],
#   'final_database': 'HGNC Symbol',
#   'graph_id': 'DPM1',
#   'query_id': 'DPM1',
#   'no_corresponding': False,
#   'no_conversion': False,
#   'no_target': False}]

# %%
len(results_idtrack)
results_idtrack.keys()
results_idtrack["Kaminski_2020"].keys()
len(results_idtrack["Kaminski_2020"]["input_identifiers"])
results_idtrack["Kaminski_2020"]["input_identifiers"][:3]
# Out:
# 27
# dict_keys(['Kaminski_2020', 'Meyer_2021', 'MeyerNikolic_unpubl', 'Barbry_unpubl', 'Regev_2021', 'Thienpont_2018', 'Budinger_2020', 'Banovich_Kropski_2020', 'Sheppard_2020', 'Wunderink_2021', 'Lambrechts_2021', 'Zhang_2021', 'Duong_lungMAP_unpubl', 'Janssen_2020', 'Sun_2020', 'Gomperts_2021', 'Eils_2020', 'Schiller_2020', 'Misharin_Budinger_2018', 'Shalek_2018', 'Schiller_2021', 'Peer_Massague_2020', 'Lafyatis_2019', 'Tata_unpubl', 'Xu_2020', 'Sims_2019', 'Schultze_unpubl'])
# dict_keys(['changed_only_1_to_n', 'changed_only_1_to_1', 'alternative_target_1_to_1', 'alternative_target_1_to_n', 'matching_1_to_0', 'matching_1_to_1', 'matching_1_to_n', 'input_identifiers'])
# 45947
# [{'target_id': ['TSPAN6'],
#   'last_node': [('ENSG00000000003.15', 'TSPAN6')],
#   'final_database': 'HGNC Symbol',
#   'graph_id': 'TSPAN6',
#   'query_id': 'TSPAN6',
#   'no_corresponding': False,
#   'no_conversion': False,
#   'no_target': False},
#  {'target_id': ['TNMD'],
#   'last_node': [('ENSG00000000005.6', 'TNMD')],
#   'final_database': 'HGNC Symbol',
#   'graph_id': 'TNMD',
#   'query_id': 'TNMD',
#   'no_corresponding': False,
#   'no_conversion': False,
#   'no_target': False},
#  {'target_id': ['DPM1'],
#   'last_node': [('ENSG00000000419.14', 'DPM1')],
#   'final_database': 'HGNC Symbol',
#   'graph_id': 'DPM1',
#   'query_id': 'DPM1',
#   'no_corresponding': False,
#   'no_conversion': False,
#   'no_target': False}]

# %% [markdown]
# ### Pre-processing <a class="anchor" id="bullet3"></a>

# %%
for i in results_core.keys():
    ds = i.replace("_txt", "")
    print(ds)
    results_idtrack[ds] = dict()
    results_idtrack[ds]["input_identifiers"] = results_core[i]
# Out:
# HLCA

# %%
results_idtrack.keys()
# Out:
# dict_keys(['Kaminski_2020', 'Meyer_2021', 'MeyerNikolic_unpubl', 'Barbry_unpubl', 'Regev_2021', 'Thienpont_2018', 'Budinger_2020', 'Banovich_Kropski_2020', 'Sheppard_2020', 'Wunderink_2021', 'Lambrechts_2021', 'Zhang_2021', 'Duong_lungMAP_unpubl', 'Janssen_2020', 'Sun_2020', 'Gomperts_2021', 'Eils_2020', 'Schiller_2020', 'Misharin_Budinger_2018', 'Shalek_2018', 'Schiller_2021', 'Peer_Massague_2020', 'Lafyatis_2019', 'Tata_unpubl', 'Xu_2020', 'Sims_2019', 'Schultze_unpubl', 'HLCA'])

# %%
ds_rename = {"MeyerNikolic_unpubl": "Meyer_Nikolic_2022"}
results_idtrack[list(ds_rename.values())[0]] = results_idtrack[
    list(ds_rename.keys())[0]
]
del results_idtrack[list(ds_rename.keys())[0]]
results_idtrack.keys()
# Out:
# dict_keys(['Kaminski_2020', 'Meyer_2021', 'Barbry_unpubl', 'Regev_2021', 'Thienpont_2018', 'Budinger_2020', 'Banovich_Kropski_2020', 'Sheppard_2020', 'Wunderink_2021', 'Lambrechts_2021', 'Zhang_2021', 'Duong_lungMAP_unpubl', 'Janssen_2020', 'Sun_2020', 'Gomperts_2021', 'Eils_2020', 'Schiller_2020', 'Misharin_Budinger_2018', 'Shalek_2018', 'Schiller_2021', 'Peer_Massague_2020', 'Lafyatis_2019', 'Tata_unpubl', 'Xu_2020', 'Sims_2019', 'Schultze_unpubl', 'HLCA', 'Meyer_Nikolic_2022'])

# %% [markdown]
# #### Feature names standardisation

# %%
final_simple = dict()
temp = list(results_idtrack.keys())
for ds in temp:
    ds_n = len(results_idtrack[ds]["input_identifiers"])
    print(f"\033[0;34m====================\033[0m {ds_n} | {ds}")
    ds_dict = {"original": [], "ensembl_id": [], "new": []}
    for i in results_idtrack[ds]["input_identifiers"]:
        # assert i["query_id"] not in final_simple[ds]
        ensembl_id = ""
        symbol = ""
        if len(i["last_node"]) > 0:
            ensembl_id = i["last_node"][0][0]
        if len(i["target_id"]) > 0:
            if not re.match(r"^ENSG", i["target_id"][0]):
                symbol = i["target_id"][0]
            else:
                symbol = ensembl_id
        else:
            symbol = i["query_id"]
        ds_dict["original"].append(i["query_id"])
        ds_dict["ensembl_id"].append(ensembl_id)
        ds_dict["new"].append(symbol)
    repeats = {x: count for x, count in Counter(ds_dict["new"]).items() if count >= 2}
    repeats = list(repeats.keys())
    final_simple[ds] = pd.DataFrame(
        {
            "original": ds_dict["original"],
            "ensembl_id": ds_dict["ensembl_id"],
            "new": ds_dict["new"],
            "repeat": [i in repeats for i in ds_dict["new"]],
        }
    )
# Out:
# ==================== 45947 | Kaminski_2020
# ==================== 20922 | Meyer_2021
# ==================== 16859 | Barbry_unpubl
# ==================== 30983 | Regev_2021
# ==================== 27958 | Thienpont_2018
# ==================== 26316 | Budinger_2020
# ==================== 33694 | Banovich_Kropski_2020
# ==================== 27147 | Sheppard_2020
# ==================== 21819 | Wunderink_2021
# ==================== 33538 | Lambrechts_2021
# ==================== 18474 | Zhang_2021
# ==================== 27678 | Duong_lungMAP_unpubl
# ==================== 33538 | Janssen_2020
# ==================== 26578 | Sun_2020
# ==================== 31229 | Gomperts_2021
# ==================== 32738 | Eils_2020
# ==================== 32104 | Schiller_2020
# ==================== 27181 | Misharin_Budinger_2018
# ==================== 25328 | Shalek_2018
# ==================== 17533 | Schiller_2021
# ==================== 19222 | Peer_Massague_2020
# ==================== 22164 | Lafyatis_2019
# ==================== 31915 | Tata_unpubl
# ==================== 32738 | Xu_2020
# ==================== 60725 | Sims_2019
# ==================== 24532 | Schultze_unpubl
# ==================== 28527 | HLCA
# ==================== 33582 | Meyer_Nikolic_2022

# %%
print(ds)
temp = (
    final_simple[ds]
    .loc[~final_simple[ds]["ensembl_id"].isin([""]), :]
    .loc[~final_simple[ds]["new"].isin([""]), :]
    .loc[final_simple[ds]["repeat"], :]
    .sort_values(by=["new"])
)
temp
# Out:
# Meyer_Nikolic_2022
#          original          ensembl_id     new  repeat
# 79          ABCF2   ENSG00000033050.9   ABCF2    True
# 80        ABCF2-1   ENSG00000033050.9   ABCF2    True
# 81        ABCF2.1   ENSG00000033050.9   ABCF2    True
# 6826        ACSL6  ENSG00000164398.15   ACSL6    True
# 3172   AC026398.1  ENSG00000164398.15   ACSL6    True
# ...           ...                 ...     ...     ...
# 165    AC002310.4   ENSG00000261459.1  ZNF747    True
# 1275   AC008770.2   ENSG00000267179.1  ZNF763    True
# 33433      ZNF763  ENSG00000197054.12  ZNF763    True
# 816    AC006978.2  ENSG00000180233.11   ZNRF2    True
# 33521       ZNRF2  ENSG00000180233.11   ZNRF2    True
#
# [1460 rows x 4 columns]

# %%
feature_old = {}
for ds in results_idtrack.keys():
    print(f"\033[94m*******************\033[0m {ds}")
    with open(f"{feats_dir}/{ds}.txt") as f:
        feature_old[ds] = [line[:-1] for line in f]
    temp = list(feature_old[ds])
    tvar = list(final_simple[ds]["ensembl_id"])
    brie = list(final_simple[ds]["original"])
    ephe = list(final_simple[ds]["new"])
    print(f"({len(temp)}) read:", temp[:3])
    print(f"({len(tvar)}) ense:", tvar[:3])
    print(f"({len(brie)}) orig:", brie[:3])
    print(f"({len(ephe)}) symb:", ephe[:3])
# Out:
# ******************* Kaminski_2020
# (45947) read: ['TSPAN6', 'TNMD', 'DPM1']
# (45947) ense: ['ENSG00000000003.15', 'ENSG00000000005.6', 'ENSG00000000419.14']
# (45947) orig: ['TSPAN6', 'TNMD', 'DPM1']
# (45947) symb: ['TSPAN6', 'TNMD', 'DPM1']
# ******************* Meyer_2021
# (20922) read: ['FAM87B', 'LINC00115', 'FAM41C']
# (20922) ense: ['ENSG00000177757.2', 'ENSG00000225880.6', 'ENSG00000230368.2']
# (20922) orig: ['FAM87B', 'LINC00115', 'FAM41C']
# (20922) symb: ['FAM87B', 'LINC00115', 'FAM41C']
# ******************* Barbry_unpubl
# (16859) read: ['ST6GALNAC6', 'TAF10', 'AL031595.3']
# (16859) ense: ['ENSG00000160408.16', 'ENSG00000166337.11', 'ENSG00000280434.1']
# (16859) orig: ['ST6GALNAC6', 'TAF10', 'AL031595.3']
# (16859) symb: ['ST6GALNAC6', 'TAF10', 'ENSG00000280434.1']
# ******************* Regev_2021
# (30983) read: ['A1BG', 'A1BG-AS1', 'A1CF']
# (30983) ense: ['ENSG00000121410.12', 'ENSG00000268895.6', 'ENSG00000148584.15']
# (30983) orig: ['A1BG', 'A1BG-AS1', 'A1CF']
# (30983) symb: ['A1BG', 'A1BG-AS1', 'A1CF']
# ******************* Thienpont_2018
# (27958) read: ['RP11-34P13.3', 'RP11-34P13.7', 'RP11-34P13.8']
# (27958) ense: ['ENSG00000243485.5', 'ENSG00000238009.6', 'ENSG00000239945.1']
# (27958) orig: ['RP11-34P13.3', 'RP11-34P13.7', 'RP11-34P13.8']
# (27958) symb: ['MIR1302-2HG', 'ENSG00000238009.6', 'ENSG00000239945.1']
# ******************* Budinger_2020
# (26316) read: ['A1BG', 'A1BG-AS1', 'A2M']
# (26316) ense: ['ENSG00000121410.12', 'ENSG00000268895.6', 'ENSG00000175899.15']
# (26316) orig: ['A1BG', 'A1BG-AS1', 'A2M']
# (26316) symb: ['A1BG', 'A1BG-AS1', 'A2M']
# ******************* Banovich_Kropski_2020
# (33694) read: ['RP11-34P13.3', 'FAM138A', 'OR4F5']
# (33694) ense: ['ENSG00000243485.5', 'ENSG00000237613.2', 'ENSG00000186092.7']
# (33694) orig: ['RP11-34P13.3', 'FAM138A', 'OR4F5']
# (33694) symb: ['MIR1302-2HG', 'FAM138A', 'OR4F5']
# ******************* Sheppard_2020
# (27147) read: ['RP11-34P13.7', 'RP11-34P13.8', 'RP11-34P13.9']
# (27147) ense: ['ENSG00000238009.6', 'ENSG00000239945.1', 'ENSG00000241599.1']
# (27147) orig: ['RP11-34P13.7', 'RP11-34P13.8', 'RP11-34P13.9']
# (27147) symb: ['ENSG00000238009.6', 'ENSG00000239945.1', 'ENSG00000241599.1']
# ******************* Wunderink_2021
# (21819) read: ['A1BG', 'A1BG-AS1', 'A2M']
# (21819) ense: ['ENSG00000121410.12', 'ENSG00000268895.6', 'ENSG00000175899.15']
# (21819) orig: ['A1BG', 'A1BG-AS1', 'A2M']
# (21819) symb: ['A1BG', 'A1BG-AS1', 'A2M']
# ******************* Lambrechts_2021
# (33538) read: ['MIR1302-2HG', 'FAM138A', 'OR4F5']
# (33538) ense: ['ENSG00000243485.5', 'ENSG00000237613.2', 'ENSG00000186092.7']
# (33538) orig: ['MIR1302-2HG', 'FAM138A', 'OR4F5']
# (33538) symb: ['MIR1302-2HG', 'FAM138A', 'OR4F5']
# ******************* Zhang_2021
# (18474) read: ['FAM87B', 'LINC00115', 'FAM41C']
# (18474) ense: ['ENSG00000177757.2', 'ENSG00000225880.6', 'ENSG00000230368.2']
# (18474) orig: ['FAM87B', 'LINC00115', 'FAM41C']
# (18474) symb: ['FAM87B', 'LINC00115', 'FAM41C']
# ******************* Duong_lungMAP_unpubl
# (27678) read: ['A1BG', 'A1BG-AS1', 'A1CF']
# (27678) ense: ['ENSG00000121410.12', 'ENSG00000268895.6', 'ENSG00000148584.15']
# (27678) orig: ['A1BG', 'A1BG-AS1', 'A1CF']
# (27678) symb: ['A1BG', 'A1BG-AS1', 'A1CF']
# ******************* Janssen_2020
# (33538) read: ['MIR1302-2HG', 'FAM138A', 'OR4F5']
# (33538) ense: ['ENSG00000243485.5', 'ENSG00000237613.2', 'ENSG00000186092.7']
# (33538) orig: ['MIR1302-2HG', 'FAM138A', 'OR4F5']
# (33538) symb: ['MIR1302-2HG', 'FAM138A', 'OR4F5']
# ******************* Sun_2020
# (26578) read: ['AL627309.1', 'AC114498.1', 'AL669831.5']
# (26578) ense: ['ENSG00000238009.6', 'ENSG00000235146.2', 'ENSG00000283040.1']
# (26578) orig: ['AL627309.1', 'AC114498.1', 'AL669831.5']
# (26578) symb: ['ENSG00000238009.6', 'ENSG00000235146.2', 'ENSG00000283040.1']
# ******************* Gomperts_2021
# (31229) read: ['AL627309.1', 'AL669831.5', 'LINC00115']
# (31229) ense: ['ENSG00000238009.6', 'ENSG00000283040.1', 'ENSG00000225880.6']
# (31229) orig: ['AL627309.1', 'AL669831.5', 'LINC00115']
# (31229) symb: ['ENSG00000238009.6', 'ENSG00000283040.1', 'LINC00115']
# ******************* Eils_2020
# (32738) read: ['MIR1302-10', 'FAM138A', 'OR4F5']
# (32738) ense: ['ENSG00000284557.1', 'ENSG00000237613.2', 'ENSG00000186092.7']
# (32738) orig: ['MIR1302-10', 'FAM138A', 'OR4F5']
# (32738) symb: ['MIR1302-10', 'FAM138A', 'OR4F5']
# ******************* Schiller_2020
# (32104) read: ['A1BG', 'A1BG-AS1', 'A2M']
# (32104) ense: ['ENSG00000121410.12', 'ENSG00000268895.6', 'ENSG00000175899.15']
# (32104) orig: ['A1BG', 'A1BG-AS1', 'A2M']
# (32104) symb: ['A1BG', 'A1BG-AS1', 'A2M']
# ******************* Misharin_Budinger_2018
# (27181) read: ['RP11-34P13.7', 'RP11-34P13.8', 'RP11-34P13.9']
# (27181) ense: ['ENSG00000238009.6', 'ENSG00000239945.1', 'ENSG00000241599.1']
# (27181) orig: ['RP11-34P13.7', 'RP11-34P13.8', 'RP11-34P13.9']
# (27181) symb: ['ENSG00000238009.6', 'ENSG00000239945.1', 'ENSG00000241599.1']
# ******************* Shalek_2018
# (25328) read: ['A1BG', 'A1BG-AS1', 'A2M']
# (25328) ense: ['ENSG00000121410.12', 'ENSG00000268895.6', 'ENSG00000175899.15']
# (25328) orig: ['A1BG', 'A1BG-AS1', 'A2M']
# (25328) symb: ['A1BG', 'A1BG-AS1', 'A2M']
# ******************* Schiller_2021
# (17533) read: ['SAMD11', 'NOC2L', 'KLHL17']
# (17533) ense: ['ENSG00000187634.13', 'ENSG00000188976.11', 'ENSG00000187961.15']
# (17533) orig: ['SAMD11', 'NOC2L', 'KLHL17']
# (17533) symb: ['SAMD11', 'NOC2L', 'KLHL17']
# ******************* Peer_Massague_2020
# (19222) read: ['A1BG', 'A1CF', 'A2M']
# (19222) ense: ['ENSG00000121410.12', 'ENSG00000148584.15', 'ENSG00000175899.15']
# (19222) orig: ['A1BG', 'A1CF', 'A2M']
# (19222) symb: ['A1BG', 'A1CF', 'A2M']
# ******************* Lafyatis_2019
# (22164) read: ['FAM138A', 'OR4F5', 'OR4F29']
# (22164) ense: ['ENSG00000237613.2', 'ENSG00000186092.7', 'ENSG00000284733.2']
# (22164) orig: ['FAM138A', 'OR4F5', 'OR4F29']
# (22164) symb: ['FAM138A', 'OR4F5', 'OR4F29']
# ******************* Tata_unpubl
# (31915) read: ['MIR1302-2HG', 'FAM138A', 'OR4F5']
# (31915) ense: ['ENSG00000243485.5', 'ENSG00000237613.2', 'ENSG00000186092.7']
# (31915) orig: ['MIR1302-2HG', 'FAM138A', 'OR4F5']
# (31915) symb: ['MIR1302-2HG', 'FAM138A', 'OR4F5']
# ******************* Xu_2020
# (32738) read: ['MIR1302-10', 'FAM138A', 'OR4F5']
# (32738) ense: ['ENSG00000284557.1', 'ENSG00000237613.2', 'ENSG00000186092.7']
# (32738) orig: ['MIR1302-10', 'FAM138A', 'OR4F5']
# (32738) symb: ['MIR1302-10', 'FAM138A', 'OR4F5']
# ******************* Sims_2019
# (60725) read: ['TIGD2', 'DMWD', 'C6orf3']
# (60725) ense: ['ENSG00000180346.5', 'ENSG00000185800.12', 'ENSG00000255389.1']
# (60725) orig: ['TIGD2', 'DMWD', 'C6orf3']
# (60725) symb: ['TIGD2', 'DMWD', 'TRAF3IP2-AS1']
# ******************* Schultze_unpubl
# (24532) read: ['MT-CO1', 'CCDC88A', 'CCL3']
# (24532) ense: ['ENSG00000198804.2', 'ENSG00000115355.18', 'ENSG00000274221.2']
# (24532) orig: ['MT-CO1', 'CCDC88A', 'CCL3']
# (24532) symb: ['MT-CO1', 'CCDC88A', 'CCL3']
# ******************* HLCA
# (28527) read: ['TSPAN6', 'TNMD', 'DPM1']
# (28527) ense: ['ENSG00000000003.15', 'ENSG00000000005.6', 'ENSG00000000419.14']
# (28527) orig: ['TSPAN6', 'TNMD', 'DPM1']
# (28527) symb: ['TSPAN6', 'TNMD', 'DPM1']
# ******************* Meyer_Nikolic_2022
# (33582) read: ['A1BG', 'A1BG-AS1', 'A1CF']
# (33582) ense: ['ENSG00000121410.12', 'ENSG00000268895.6', 'ENSG00000148584.15']
# (33582) orig: ['A1BG', 'A1BG-AS1', 'A1CF']
# (33582) symb: ['A1BG', 'A1BG-AS1', 'A1CF']

# %% [markdown]
# ### Main <a class="anchor" id="bullet4"></a>

# %% [markdown]
# Expand shared ones

# %%
feature_conversion = final_simple.copy()
for ds_merged in adata_split.keys():
    print(f"\033[1m\033[93mExpanding\033[0m {ds_merged}")
    ds_column = list(adata_split[ds_merged].keys())[0]
    for ds in adata_split[ds_merged][ds_column]:
        feature_conversion[ds] = feature_conversion[ds_merged]
    del feature_conversion[ds_merged]
# Out:
# Expanding HLCA

# %% [markdown]
# Concatenate to pivot create a table with studies as columns.

# %%
temp = list(final_simple.keys())
feature_conversion_all = final_simple[temp[0]].copy()
feature_conversion_all["study"] = temp[0]
for ds in temp[1:]:
    tvar = final_simple[ds].copy()
    tvar["study"] = ds.replace("HLCA", "Core")
    feature_conversion_all = pd.concat(
        [feature_conversion_all, tvar], axis=0, ignore_index=True
    )
feature_conversion_all
# Out:
#             original          ensembl_id           new  repeat  \
# 0             TSPAN6  ENSG00000000003.15        TSPAN6   False
# 1               TNMD   ENSG00000000005.6          TNMD   False
# 2               DPM1  ENSG00000000419.14          DPM1   False
# 3              SCYL3  ENSG00000000457.14         SCYL3   False
# 4           C1orf112  ENSG00000000460.17      C1ORF112   False
# ...              ...                 ...           ...     ...
# 810964        ZYG11A  ENSG00000203995.10        ZYG11A   False
# 810965        ZYG11B  ENSG00000162378.13        ZYG11B   False
# 810966           ZYX   ENSG00000285443.2           ZYX   False
# 810967         ZZEF1  ENSG00000074755.15         ZZEF1   False
# 810968  hsa-mir-1253                      hsa-mir-1253   False
#
#                      study
# 0            Kaminski_2020
# 1            Kaminski_2020
# 2            Kaminski_2020
# 3            Kaminski_2020
# 4            Kaminski_2020
# ...                    ...
# 810964  Meyer_Nikolic_2022
# 810965  Meyer_Nikolic_2022
# 810966  Meyer_Nikolic_2022
# 810967  Meyer_Nikolic_2022
# 810968  Meyer_Nikolic_2022
#
# [810969 rows x 5 columns]

# %%
temp = len(set(feature_conversion_all["new"].tolist()))
print(f"Total: {temp}")
# Out:
# Total: 59574

# %%
temp = feature_conversion_all.loc[
    feature_conversion_all["new"].isin(["HLA-B"]), :
]  # GTF2H2
temp.sort_values(by=["study"])
# Out:
#        original          ensembl_id    new  repeat                   study
# 179604    HLA-B  ENSG00000224608.10  HLA-B   False   Banovich_Kropski_2020
# 70495     HLA-B  ENSG00000224608.10  HLA-B   False           Barbry_unpubl
# 155894    HLA-B  ENSG00000224608.10  HLA-B   False           Budinger_2020
# 768997    HLA-B  ENSG00000224608.10  HLA-B   False                    Core
# 318193    HLA-B  ENSG00000224608.10  HLA-B   False    Duong_lungMAP_unpubl
# 433274    HLA-B  ENSG00000224608.10  HLA-B   False               Eils_2020
# 397023    HLA-B  ENSG00000224608.10  HLA-B   False           Gomperts_2021
# 341942    HLA-B  ENSG00000224608.10  HLA-B   False            Janssen_2020
# 20934     HLA-B  ENSG00000224608.10  HLA-B   False           Kaminski_2020
# 583854    HLA-B  ENSG00000224608.10  HLA-B   False           Lafyatis_2019
# 262252    HLA-B  ENSG00000224608.10  HLA-B   False         Lambrechts_2021
# 52709     HLA-B  ENSG00000224608.10  HLA-B   False              Meyer_2021
# 795199    HLA-B  ENSG00000224608.10  HLA-B   False      Meyer_Nikolic_2022
# 496118    HLA-B  ENSG00000224608.10  HLA-B   False  Misharin_Budinger_2018
# 564506    HLA-B  ENSG00000224608.10  HLA-B   False      Peer_Massague_2020
# 100224    HLA-B  ENSG00000224608.10  HLA-B   False              Regev_2021
# 463020    HLA-B  ENSG00000224608.10  HLA-B   False           Schiller_2020
# 545623    HLA-B  ENSG00000224608.10  HLA-B   False           Schiller_2021
# 724559    HLA-B  ENSG00000224608.10  HLA-B   False         Schultze_unpubl
# 521316    HLA-B  ENSG00000224608.10  HLA-B   False             Shalek_2018
# 211272    HLA-B  ENSG00000224608.10  HLA-B   False           Sheppard_2020
# 699133    HLA-B  ENSG00000224608.10  HLA-B   False               Sims_2019
# 372225    HLA-B  ENSG00000224608.10  HLA-B   False                Sun_2020
# 609091    HLA-B  ENSG00000224608.10  HLA-B   False             Tata_unpubl
# 123568    HLA-B  ENSG00000224608.10  HLA-B   False          Thienpont_2018
# 240087    HLA-B  ENSG00000224608.10  HLA-B   False          Wunderink_2021
# 641459    HLA-B  ENSG00000224608.10  HLA-B   False                 Xu_2020
# 290994    HLA-B  ENSG00000224608.10  HLA-B   False              Zhang_2021

# %%
artifacts = [" " in i or "\n" in i for i in feature_conversion_all["new"]]
feature_conversion_all.loc[artifacts, :]
# Out:
# Empty DataFrame
# Columns: [original, ensembl_id, new, repeat, study]
# Index: []

# %%
feature_conversion_all.loc[artifacts & feature_conversion_all["repeat"], :].sort_values(
    by=["new", "study"]
)
# Out:
# Empty DataFrame
# Columns: [original, ensembl_id, new, repeat, study]
# Index: []

# %%
feats_out_table = re.sub("-with-core.pk", "_table_flat.csv", feats_inp)
feats_out_table
# Out:
# '../../data/HLCA_extended/extension_datasets/features/all_update_table_flat.csv'

# %%
feature_conversion_all.to_csv(feats_out_table)

# %%
# %%time
feature_conversion_all["old_aggr"] = feature_conversion_all.groupby(["new", "study"])[
    "original"
].transform(lambda x: ";".join(x))
# Out:
# CPU times: user 58 s, sys: 1.23 s, total: 59.2 s
# Wall time: 59.4 s

# %%
feature_conversion_all.loc[feature_conversion_all["repeat"], :].sort_values(
    by=["new", "study"]
)
# Out:
#              original          ensembl_id          new  repeat          study  \
# 411948    AADACL2-AS1   ENSG00000262466.5  AADACL2-AS1    True  Gomperts_2021
# 421058  RP11-454C18.2   ENSG00000262466.5  AADACL2-AS1    True  Gomperts_2021
# 671366     AC069067.1   ENSG00000262466.5  AADACL2-AS1    True      Sims_2019
# 717146    AADACL2-AS1   ENSG00000262466.5  AADACL2-AS1    True      Sims_2019
# 408801          AATBC   ENSG00000215458.8        AATBC    True  Gomperts_2021
# ...               ...                 ...          ...     ...            ...
# 412680           ZZZ3  ENSG00000036549.13         ZZZ3    True  Gomperts_2021
# 476416           ZZZ3  ENSG00000036549.13         ZZZ3    True  Schiller_2020
# 482250     AC118549.1  ENSG00000036549.13         ZZZ3    True  Schiller_2020
# 398996           DKC1  ENSG00000130826.19         dkc1    True  Gomperts_2021
# 420305        MIR644B  ENSG00000130826.19         dkc1    True  Gomperts_2021
#
#                          old_aggr
# 411948  AADACL2-AS1;RP11-454C18.2
# 421058  AADACL2-AS1;RP11-454C18.2
# 671366     AC069067.1;AADACL2-AS1
# 717146     AC069067.1;AADACL2-AS1
# 408801            AATBC;LOC284837
# ...                           ...
# 412680            AC118549.1;ZZZ3
# 476416            ZZZ3;AC118549.1
# 482250            ZZZ3;AC118549.1
# 398996               DKC1;MIR644B
# 420305               DKC1;MIR644B
#
# [42565 rows x 6 columns]

# %%
df = feature_conversion_all.drop_duplicates(subset=["new", "study"])
df.shape
# Out:
# (787718, 6)

# %%
df.loc[df["repeat"], :].sort_values(by=["new", "study"])
# Out:
#            original          ensembl_id          new  repeat          study  \
# 411948  AADACL2-AS1   ENSG00000262466.5  AADACL2-AS1    True  Gomperts_2021
# 671366   AC069067.1   ENSG00000262466.5  AADACL2-AS1    True      Sims_2019
# 408801        AATBC   ENSG00000215458.8        AATBC    True  Gomperts_2021
# 456790  AP001053.11   ENSG00000215458.8        AATBC    True  Schiller_2020
# 670632   AC092375.1   ENSG00000257408.2      ABCA3P1    True      Sims_2019
# ...             ...                 ...          ...     ...            ...
# 397476         ZUP1  ENSG00000153975.10         ZUP1    True  Gomperts_2021
# 476405        ZUFSP  ENSG00000153975.10         ZUP1    True  Schiller_2020
# 392189   AC118549.1  ENSG00000036549.13         ZZZ3    True  Gomperts_2021
# 476416         ZZZ3  ENSG00000036549.13         ZZZ3    True  Schiller_2020
# 398996         DKC1  ENSG00000130826.19         dkc1    True  Gomperts_2021
#
#                          old_aggr
# 411948  AADACL2-AS1;RP11-454C18.2
# 671366     AC069067.1;AADACL2-AS1
# 408801            AATBC;LOC284837
# 456790          AP001053.11;AATBC
# 670632   AC092375.1;RP11-645C24.4
# ...                           ...
# 397476                 ZUP1;ZUFSP
# 476405                 ZUFSP;ZUP1
# 392189            AC118549.1;ZZZ3
# 476416            ZZZ3;AC118549.1
# 398996               DKC1;MIR644B
#
# [19314 rows x 6 columns]

# %%
feature_conversion_df = df.pivot(
    index="new", columns="study", values="old_aggr"
).reset_index()
feature_conversion_df.shape
feature_conversion_df
# Out:
# (59574, 29)
# study       new Banovich_Kropski_2020 Barbry_unpubl Budinger_2020      Core  \
# 0         1-DEC                   NaN           NaN           NaN       NaN
# 1          A1BG                  A1BG          A1BG          A1BG      A1BG
# 2      A1BG-AS1              A1BG-AS1           NaN      A1BG-AS1  A1BG-AS1
# 3          A1CF                  A1CF           NaN           NaN      A1CF
# 4           A2M                   A2M           NaN           A2M       A2M
# ...         ...                   ...           ...           ...       ...
# 59569     rab1b                 RAB1B         RAB1B         RAB1B     RAB1B
# 59570      stc1                  STC1           NaN          STC1      STC1
# 59571    stxbp1                STXBP1        STXBP1        STXBP1    STXBP1
# 59572       tec                   TEC           TEC           TEC       TEC
# 59573      wfs1                  WFS1          WFS1          WFS1      WFS1
#
# study Duong_lungMAP_unpubl Eils_2020 Gomperts_2021 Janssen_2020 Kaminski_2020  \
# 0                      NaN       NaN         1-DEC          NaN           NaN
# 1                     A1BG      A1BG          A1BG         A1BG          A1BG
# 2                 A1BG-AS1  A1BG-AS1      A1BG-AS1     A1BG-AS1      A1BG-AS1
# 3                     A1CF      A1CF          A1CF         A1CF          A1CF
# 4                      A2M       A2M           A2M          A2M           A2M
# ...                    ...       ...           ...          ...           ...
# 59569                RAB1B     RAB1B         RAB1B        RAB1B         RAB1B
# 59570                 STC1      STC1          STC1         STC1          STC1
# 59571               STXBP1    STXBP1        STXBP1       STXBP1        STXBP1
# 59572                  TEC       TEC           TEC          TEC           TEC
# 59573                 WFS1      WFS1          WFS1         WFS1          WFS1
#
# study  ... Schultze_unpubl Shalek_2018 Sheppard_2020 Sims_2019  Sun_2020  \
# 0      ...             NaN         NaN           NaN       NaN       NaN
# 1      ...            A1BG        A1BG          A1BG      A1BG      A1BG
# 2      ...        A1BG-AS1    A1BG-AS1      A1BG-AS1  A1BG-AS1  A1BG-AS1
# 3      ...             NaN         NaN          A1CF      A1CF      A1CF
# 4      ...             A2M         A2M           A2M       A2M       A2M
# ...    ...             ...         ...           ...       ...       ...
# 59569  ...           RAB1B       RAB1B         RAB1B     RAB1B     RAB1B
# 59570  ...            STC1        STC1          STC1      STC1      STC1
# 59571  ...          STXBP1      STXBP1        STXBP1    STXBP1    STXBP1
# 59572  ...             TEC         TEC           TEC       TEC       TEC
# 59573  ...            WFS1        WFS1          WFS1      WFS1      WFS1
#
# study Tata_unpubl Thienpont_2018 Wunderink_2021   Xu_2020 Zhang_2021
# 0             NaN            NaN            NaN       NaN        NaN
# 1            A1BG           A1BG           A1BG      A1BG       A1BG
# 2        A1BG-AS1       A1BG-AS1       A1BG-AS1  A1BG-AS1   A1BG-AS1
# 3            A1CF           A1CF            NaN      A1CF       A1CF
# 4             A2M            A2M            A2M       A2M        A2M
# ...           ...            ...            ...       ...        ...
# 59569       RAB1B          RAB1B          RAB1B     RAB1B      RAB1B
# 59570        STC1           STC1            NaN      STC1       STC1
# 59571      STXBP1         STXBP1         STXBP1    STXBP1     STXBP1
# 59572         TEC            TEC            TEC       TEC        TEC
# 59573        WFS1           WFS1           WFS1      WFS1       WFS1
#
# [59574 rows x 29 columns]

# %%
feature_conversion_df.loc[feature_conversion_df["new"].isin(["HLA-B"]), :]
# Out:
# study    new Banovich_Kropski_2020 Barbry_unpubl Budinger_2020   Core  \
# 29576  HLA-B                 HLA-B         HLA-B         HLA-B  HLA-B
#
# study Duong_lungMAP_unpubl Eils_2020 Gomperts_2021 Janssen_2020 Kaminski_2020  \
# 29576                HLA-B     HLA-B         HLA-B        HLA-B         HLA-B
#
# study  ... Schultze_unpubl Shalek_2018 Sheppard_2020 Sims_2019 Sun_2020  \
# 29576  ...           HLA-B       HLA-B         HLA-B     HLA-B    HLA-B
#
# study Tata_unpubl Thienpont_2018 Wunderink_2021 Xu_2020 Zhang_2021
# 29576       HLA-B          HLA-B          HLA-B   HLA-B      HLA-B
#
# [1 rows x 29 columns]

# %% [markdown]
# ### Conclusions <a class="anchor" id="bullet5"></a>

# %% [markdown]
# ### Save <a class="anchor" id="bullet6"></a>

# %%
feats_out_table = re.sub("-with-core.pk", "_table.csv", feats_inp)
feats_out_table
# Out:
# '../../data/HLCA_extended/extension_datasets/features/all_update_table.csv'

# %%
feature_conversion_df.to_csv(feats_out_table)

# %%
feats_out_pk = re.sub("-with-core.pk", "_digested.pk", feats_inp)
feats_out_pk
# Out:
# '../../data/HLCA_extended/extension_datasets/features/all_update_digested.pk'

# %%
with open(f"{feats_out_pk}", "wb") as handle:
    pickle.dump(feature_conversion, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# Done.
