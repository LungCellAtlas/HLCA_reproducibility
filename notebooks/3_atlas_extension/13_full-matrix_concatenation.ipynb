# %% [markdown]
# ## Concatenation of all datasets into one matrix

# %% [markdown]
# We are finally concatenating the full matrix for all datasets. This is to increase the amount of genes we are testing.

# %% [markdown]
# __author__ = "Ciro Ramírez-Suástegui"
#
# __copyright__ = "Copyright 2022-09-14, Helmholtz Zentrum Muenchen"
#
# __license__ = "GPL"
#
# __version__ = "0.0.9"
#
# __email__ = "ciro.suastegui@helmholtz-muenchen.de, ksuasteguic@gmail.com"
#
# __status__ = "Prototype"

# %% [markdown]
# #### Structure

# %% [markdown]
# * [Global variables and paths](#bullet1)
# * [Loading data](#bullet2)
# * [Pre-processing](#bullet3)
# * [Main](#bullet4)
# * [Conclusions](#bullet5)
# * [Save](#bullet6)

# %% [markdown]
# ### Environment setup

# %%
# %load_ext autoreload
# %autoreload 2
import importlib

spam_spec = importlib.util.find_spec("lab_black")
if spam_spec is not None:
    # %load_ext lab_black

# %%
# basic modules
import warnings, os, re
import time, sys
import gc
from datetime import datetime
from collections import Counter
from collections import defaultdict
import itertools

warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.simplefilter(action="ignore", category=UserWarning)

# %%
# in-house/developing modules
# tools modules
import scanpy as sc
import numpy as np
import pandas as pd
import anndata as ad

# %%
def list_duplicates(seq):
    tally = defaultdict(list)
    for i, item in enumerate(seq):
        tally[item].append(i)
    return ((key, locs) for key, locs in tally.items() if len(locs) > 1)

# %%
sc.logging.print_versions()
# Out:
# -----
# anndata     0.8.0
# scanpy      1.9.1
# -----
# 7b32b9a39ad70713acde__mypyc NA
# PIL                         9.2.0
# autoreload                  NA
# backcall                    0.2.0
# beta_ufunc                  NA
# binom_ufunc                 NA
# black                       22.6.0
# blib2to3                    NA
# cffi                        1.15.1
# click                       8.1.3
# cycler                      0.10.0
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.5.1
# decorator                   5.1.1
# defusedxml                  0.7.1
# entrypoints                 0.4
# h5py                        3.7.0
# igraph                      0.9.11
# ipykernel                   6.15.2
# ipython_genutils            0.2.0
# jedi                        0.18.2
# joblib                      1.1.0
# jupyter_server              1.23.4
# kiwisolver                  1.4.4
# lab_black                   NA
# leidenalg                   0.8.10
# llvmlite                    0.39.0
# matplotlib                  3.5.2
# mpl_toolkits                NA
# mypy_extensions             NA
# natsort                     8.1.0
# nbinom_ufunc                NA
# numba                       0.56.0
# numpy                       1.21.6
# packaging                   23.0
# pandas                      1.3.5
# parso                       0.8.3
# pathspec                    0.9.0
# pexpect                     4.8.0
# pickleshare                 0.7.5
# pkg_resources               NA
# platformdirs                2.5.2
# prompt_toolkit              3.0.36
# psutil                      5.9.0
# ptyprocess                  0.7.0
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.6.0
# pydevd_concurrency_analyser NA
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.14.0
# pyparsing                   3.0.9
# pytz                        2022.7.1
# scipy                       1.7.3
# session_info                1.0.0
# setuptools                  65.5.0
# six                         1.16.0
# sklearn                     1.0.2
# storemagic                  NA
# texttable                   1.6.4
# threadpoolctl               3.1.0
# tomli                       2.0.1
# tornado                     6.1
# traitlets                   5.8.1
# typed_ast                   1.5.4
# typing_extensions           NA
# wcwidth                     0.2.6
# zipp                        NA
# zmq                         19.0.2
# -----
# IPython             7.33.0
# jupyter_client      7.0.6
# jupyter_core        4.11.1
# jupyterlab          3.5.3
# notebook            6.5.2
# -----
# Python 3.7.13 (default, Mar 29 2022, 02:18:16) [GCC 7.5.0]
# Linux-3.10.0-1160.71.1.el7.x86_64-x86_64-with-centos-7.9.2009-Core
# -----
# Session information updated at 2023-02-07 21:46

# %%
print("Environment:", re.sub(".os.py", "", os.__file__))
parentpath = lambda _path, n: os.sep.join(_path.split(os.sep)[:-n])
print("Working at:", re.sub(parentpath(os.getcwd(), 2), "", os.getcwd()))
# Out:
# Environment: /home/icb/ciro.suastegui/miniconda3/envs/HLCA_basic/lib/python3.7
# Working at: /notebooks/3_atlas_extension

# %% [markdown]
# ### Global variables and paths <a class="anchor" id="bullet1"></a>

# %%
dset0_dir = "../../data/HLCA_extended/extension_datasets/ready/full"
feats_dir = "../../data/HLCA_extended/extension_datasets/features/"
feats_inp = (
    "../../data/HLCA_extended/extension_datasets/features/all_update_digested.pk"
)
adata_o_out = "../../data/HLCA_extended/HLCA_extended/HLCA_extended_full.h5ad"
embed_inp = "../../data/HLCA_extended/HLCA_extended/HLCA_extended_scarches_emb.h5ad"  # we need the metadata

# %%
adata_dict = {
    "HLCA": ["../../data/HLCA_core_h5ads/HLCA_v2.h5ad"],
    "Kaminski_2020": [f"{dset0_dir}/adams.h5ad"],
    "Meyer_2021": [f"{dset0_dir}/meyer_2021.h5ad"],
    "Meyer_Nikolic_2022": [f"{dset0_dir}/meyer_nikolic_unpubl.h5ad"],
    "Barbry_unpubl": [f"{dset0_dir}/barbry.h5ad"],
    "Regev_2021": [
        f"{dset0_dir}/delorey_cryo.h5ad",
        f"{dset0_dir}/delorey_fresh.h5ad",
        f"{dset0_dir}/delorey_nuclei.h5ad",
    ],
    "Thienpont_2018": [f"{dset0_dir}/lambrechts.h5ad"],
    "Budinger_2020": [f"{dset0_dir}/bharat.h5ad"],
    "Banovich_Kropski_2020": [f"{dset0_dir}/haberman.h5ad"],
    "Sheppard_2020": [f"{dset0_dir}/tsukui.h5ad"],
    "Wunderink_2021": [f"{dset0_dir}/grant_cryo.h5ad", f"{dset0_dir}/grant_fresh.h5ad"],
    "Lambrechts_2021": [
        f"{dset0_dir}/wouters.h5ad"  # , f"{dset0_dir}/wouters_labs.h5ad"
    ],
    "Zhang_2021": [f"{dset0_dir}/liao.h5ad"],
    "Duong_lungMAP_unpubl": [f"{dset0_dir}/duong.h5ad"],
    "Janssen_2020": [f"{dset0_dir}/mould.h5ad"],  # duplicated cells
    "Sun_2020": [
        f"{dset0_dir}/wang_sub_batch1.h5ad",
        f"{dset0_dir}/wang_sub_batch2.h5ad",
        f"{dset0_dir}/wang_sub_batch3.h5ad",
        f"{dset0_dir}/wang_sub_batch4.h5ad",
    ],
    "Gomperts_2021": [
        f"{dset0_dir}/carraro_ucla.h5ad",
        f"{dset0_dir}/carraro_cff.h5ad",
        f"{dset0_dir}/carraro_csmc.h5ad",
    ],
    "Eils_2020": [f"{dset0_dir}/lukassen.h5ad"],
    "Schiller_2020": [f"{dset0_dir}/mayr.h5ad"],
    "Misharin_Budinger_2018": [f"{dset0_dir}/reyfman_disease.h5ad"],
    "Shalek_2018": [f"{dset0_dir}/ordovasmontanes.h5ad"],
    "Schiller_2021": [f"{dset0_dir}/schiller_discovair.h5ad"],
    "Peer_Massague_2020": [f"{dset0_dir}/laughney.h5ad"],
    "Lafyatis_2019": [f"{dset0_dir}/valenzi.h5ad"],
    "Tata_unpubl": [f"{dset0_dir}/tata_unpubl.h5ad"],
    "Xu_2020": [f"{dset0_dir}/guo.h5ad"],
    "Sims_2019": [f"{dset0_dir}/szabo.h5ad"],
    "Schultze_unpubl": [f"{dset0_dir}/schultze_unpubl.h5ad"],
}

# %%
adata_split = {"HLCA": {"study": []}}

# %% [markdown]
# ### Loading data <a class="anchor" id="bullet2"></a>

# %%
feature_conversion = pd.read_pickle(feats_inp)

# %%
feature_conversion.keys()
# Out:
# dict_keys(['Kaminski_2020', 'Meyer_2021', 'Barbry_unpubl', 'Regev_2021', 'Thienpont_2018', 'Budinger_2020', 'Banovich_Kropski_2020', 'Sheppard_2020', 'Wunderink_2021', 'Lambrechts_2021', 'Zhang_2021', 'Duong_lungMAP_unpubl', 'Janssen_2020', 'Sun_2020', 'Gomperts_2021', 'Eils_2020', 'Schiller_2020', 'Misharin_Budinger_2018', 'Shalek_2018', 'Schiller_2021', 'Peer_Massague_2020', 'Lafyatis_2019', 'Tata_unpubl', 'Xu_2020', 'Sims_2019', 'Schultze_unpubl', 'Meyer_Nikolic_2022', 'Nawijn_2021_HLCA', 'Barbry_Leroy_2020_HLCA', 'Meyer_2019_HLCA', 'Banovich_Kropski_2020_HLCA', 'Seibold_2020_HLCA', 'Jain_Misharin_2021_HLCA', 'Teichmann_Meyer_2019_HLCA', 'Misharin_2021_HLCA', 'Lafyatis_Rojas_2019_HLCA', 'Krasnow_2020_HLCA', 'Misharin_Budinger_2018_HLCA'])

# %%
feature_conversion["Kaminski_2020"]
# Out:
#               original          ensembl_id                new  repeat
# 0               TSPAN6  ENSG00000000003.15             TSPAN6   False
# 1                 TNMD   ENSG00000000005.6               TNMD   False
# 2                 DPM1  ENSG00000000419.14               DPM1   False
# 3                SCYL3  ENSG00000000457.14              SCYL3   False
# 4             C1orf112  ENSG00000000460.17           C1ORF112   False
# ...                ...                 ...                ...     ...
# 45942  ENSG00000227029   ENSG00000227029.1  ENSG00000227029.1   False
# 45943        RN7SL782P   ENSG00000239708.3          RN7SL782P   False
# 45944  ENSG00000274532   ENSG00000274532.1  ENSG00000274532.1   False
# 45945  ENSG00000277705   ENSG00000277705.1  ENSG00000277705.1   False
# 45946  ENSG00000280139   ENSG00000280139.1  ENSG00000280139.1   False
#
# [45947 rows x 4 columns]

# %%
# %%time
adatas = dict()
for ds in adata_dict.keys():
    ds_files = adata_dict[ds]
    if all([os.path.isfile(i) for i in ds_files]):
        print(f"\033[92m*******************\033[0m {ds}", end=" ")
    else:
        print(f"\033[1m\033[91m*******************\033[0m {ds}", end=" ")
    if len(ds_files) == 1:
        print(f"\033[1m\033[97mS\033[0m", end="")
        adatas[ds] = sc.read(ds_files[0])
    else:
        print(f"\033[1m\033[94mM\033[0m", end="")
        ds_adatas = dict()
        for ds_f in ds_files:
            print(".", end="")
            ds_adatas[ds_f] = sc.read(ds_f)
        adatas[ds] = sc.AnnData.concatenate(
            *ds_adatas.values(), join="outer",
            batch_key=None,
            # batch_categories=[re.sub(".*/|.h5ad", "", i) for i in ds_files],
            index_unique=None # "_"
        )
        del ds_adatas
    print("")
    del adatas[ds].uns
    del adatas[ds].obsm
    del adatas[ds].varm
    del adatas[ds].obsp
    print(adatas[ds].shape)
    if len(adatas[ds].layers) > 0:
        temp = list(adatas[ds].layers.keys())
        print("Layers found:", ", ".join(temp), f"- using {temp[0]}")
        adatas[ds].X = adatas[ds].layers[temp[0]].copy()
        del adatas[ds].layers
    if ds in adata_split.keys():
        print(f"\033[1m\033[93mFor splitting\033[0m")
        ds_column = list(adata_split[ds].keys())[0]
        for ds_i in list(set(adatas[ds].obs[ds_column])):
            print(f" {ds_i}", end=" ")
            ds_new = ds_i + "_" + ds
            if not ds_new in adata_split[ds][ds_column]:
                adata_split[ds][ds_column].append(ds_new)
            adatas[ds_new] = adatas[ds][adatas[ds].obs[ds_column] == ds_i].copy()
            print(f"{adatas[ds_new].shape}")
        del adatas[ds]
# Out:
# ******************* HLCA S
# (584944, 28527)
# Layers found: counts - using counts
# For splitting
#  Lafyatis_Rojas_2019 (24181, 28527)
#  Banovich_Kropski_2020 (121894, 28527)
#  Nawijn_2021 (70402, 28527)
#  Seibold_2020 (33593, 28527)
#  Misharin_2021 (64843, 28527)
#  Teichmann_Meyer_2019 (12231, 28527)
#  Jain_Misharin_2021 (45557, 28527)
#  Meyer_2019 (35554, 28527)
#  Barbry_Leroy_2020 (74487, 28527)
#  Krasnow_2020 (60982, 28527)
#  Misharin_Budinger_2018 (41220, 28527)
# ******************* Kaminski_2020 S
# (307650, 45947)
# ******************* Meyer_2021 S
# (129340, 20922)
# ******************* Meyer_Nikolic_2022 S
# (236977, 33582)
# ******************* Barbry_unpubl S
# (100211, 16859)
# ******************* Regev_2021 M...
# (96060, 30983)
# ******************* Thienpont_2018 S
# (93575, 27958)
# ******************* Budinger_2020 S
# (91980, 26316)
# ******************* Banovich_Kropski_2020 S
# (82692, 33694)
# ******************* Sheppard_2020 S
# (80020, 27147)
# ******************* Wunderink_2021 M..
# (77146, 21819)
# ******************* Lambrechts_2021 S
# (65166, 33538)
# ******************* Zhang_2021 S
# (62469, 18474)
# ******************* Duong_lungMAP_unpubl S
# (53904, 27678)
# ******************* Janssen_2020 S
# (49384, 33538)
# ******************* Sun_2020 M....
# (46500, 26578)
# ******************* Gomperts_2021 M...
# (40709, 31229)
# ******************* Eils_2020 S
# (39778, 32738)
# ******************* Schiller_2020 S
# (38648, 32104)
# ******************* Misharin_Budinger_2018 S
# (37097, 27181)
# ******************* Shalek_2018 S
# (36740, 25328)
# ******************* Schiller_2021 S
# (35984, 17533)
# ******************* Peer_Massague_2020 S
# (32850, 19222)
# ******************* Lafyatis_2019 S
# (27297, 22164)
# ******************* Tata_unpubl S
# (21700, 31915)
# ******************* Xu_2020 S
# (12374, 32738)
# ******************* Sims_2019 S
# (10790, 60725)
# ******************* Schultze_unpubl S
# (8016, 24532)
# CPU times: user 23.6 s, sys: 1min 24s, total: 1min 48s
# Wall time: 1min 55s

# %%
embed = sc.read(embed_inp, backed="r")

# %%
embed
# Out:
# AnnData object with n_obs × n_vars = 2382658 × 30 backed at '../../data/HLCA_extended/HLCA_extended/HLCA_extended_scarches_emb.h5ad'
#     obs: 'sample', 'original_celltype_ann', 'study_long', 'study', 'last_author_PI', 'subject_ID', 'subject_ID_as_published', 'pre_or_postnatal', 'age_in_years', 'age_range', 'sex', 'smoking_status', 'smoking_history', 'BMI', 'known_lung_disease', 'condition', 'subject_type', 'cause_of_death', 'sample_type', 'anatomical_region_coarse', 'anatomical_region_detailed', 'tissue_dissociation_protocol', 'cells_or_nuclei', 'single_cell_platform', "3'_or_5'", 'enrichment', 'sequencing_platform', 'reference_genome_coarse', 'ensembl_release_reference_genome', 'cell_ranger_version', 'disease_status', 'fresh_or_frozen', 'cultured', 'cell_viability_%', 'comments', 'Processing_site', 'dataset', 'anatomical_region_level_1', 'anatomical_region_level_2', 'anatomical_region_level_3', 'anatomical_region_highest_res', 'age', 'ann_level_1', 'ann_level_2', 'ann_level_3', 'ann_level_4', 'ann_level_5', 'ann_highest_res', 'ann_new', 'n_genes', 'total_counts', 'log10_total_counts', 'n_genes_detected', 'mito_frac', 'ribo_frac', 'compl', 'size_factors', 'ann_level_1_clean', 'ann_level_2_clean', 'ann_level_3_clean', 'ann_level_4_clean', 'ann_level_5_clean', 'scanvi_label', 'leiden_1', 'leiden_2', 'leiden_3', 'anatomical_region_ccf_score', 'manual_ann', 'leiden_4', 'reannotation_type', 'leiden_5', 'original_ann_level_1', 'original_ann_level_2', 'original_ann_level_3', 'original_ann_level_4', 'original_ann_level_5', 'original_ann_highest_res', 'original_ann_new', 'original_ann_level_1_clean', 'original_ann_level_2_clean', 'original_ann_level_3_clean', 'original_ann_level_4_clean', 'original_ann_level_5_clean', 'cluster_annotated', 'manual_ann_grouped', 'entropy_subject_ID_leiden_3', 'entropy_dataset_leiden_3', 'entropy_original_ann_level_1_leiden_3', 'entropy_original_ann_level_2_clean_leiden_3', 'entropy_original_ann_level_3_clean_leiden_3', 'core_or_extension', 'ancestry', 'mixed_ancestry', 'transf_ann_level_1_label', 'transf_ann_level_1_uncert', 'transf_ann_level_2_label', 'transf_ann_level_2_uncert', 'transf_ann_level_3_label', 'transf_ann_level_3_uncert', 'transf_ann_level_4_label', 'transf_ann_level_4_uncert', 'transf_ann_level_5_label', 'transf_ann_level_5_uncert'
#     uns: 'ann_level_3_colors', 'manual_ann_colors', 'neighbors', 'transf_ann_level_3_label_colors', 'umap'
#     obsm: 'X_umap'
#     obsp: 'connectivities', 'distances'

# %%
embed_obs = embed.obs.copy()
del embed
gc.collect()
# Out:
# 3164

# %% [markdown]
# ### Pre-processing <a class="anchor" id="bullet3"></a>

# %%
for ds in adatas.keys():
    ds_vars = adatas[ds].var_names.tolist()
    temp = set(feature_conversion[ds]["original"]) - set(ds_vars)
    tvar = set(ds_vars) - set(feature_conversion[ds]["original"])
    if (len(temp) == 0) and (len(tvar) == 0):
        print(f"\033[92m*******************\033[0m {ds}", end="")
        if ds_vars == feature_conversion[ds]["original"].tolist():
            print(" - same order")
        else:
            print(" - \033[0;31morder off\033[0m")
    else:
        print(f"\033[1m\033[91m*******************\033[0m {ds}")
        for i in temp:
            print(
                adatas[ds].shape[1],
                len(feature_conversion[ds]["original"]),
                len(feature_conversion[ds]["new"]),
            )
            for j, nam in enumerate(feature_conversion[ds]["original"]):
                if i == feature_conversion[ds]["original"][j]:
                    oo = feature_conversion[ds]["original"][j]
                    nn = feature_conversion[ds]["new"][j]
                    print(f"Matrix: '{ds_vars[j]}', Old: '{oo}', Harmonised: '{nn}'")
# Out:
# ******************* Lafyatis_Rojas_2019_HLCA - same order
# ******************* Banovich_Kropski_2020_HLCA - same order
# ******************* Nawijn_2021_HLCA - same order
# ******************* Seibold_2020_HLCA - same order
# ******************* Misharin_2021_HLCA - same order
# ******************* Teichmann_Meyer_2019_HLCA - same order
# ******************* Jain_Misharin_2021_HLCA - same order
# ******************* Meyer_2019_HLCA - same order
# ******************* Barbry_Leroy_2020_HLCA - same order
# ******************* Krasnow_2020_HLCA - same order
# ******************* Misharin_Budinger_2018_HLCA - same order
# ******************* Kaminski_2020 - same order
# ******************* Meyer_2021 - same order
# ******************* Meyer_Nikolic_2022 - same order
# ******************* Barbry_unpubl - same order
# ******************* Regev_2021 - same order
# ******************* Thienpont_2018 - same order
# ******************* Budinger_2020 - same order
# ******************* Banovich_Kropski_2020 - same order
# ******************* Sheppard_2020 - same order
# ******************* Wunderink_2021 - same order
# ******************* Lambrechts_2021 - same order
# ******************* Zhang_2021 - same order
# ******************* Duong_lungMAP_unpubl - same order
# ******************* Janssen_2020 - same order
# ******************* Sun_2020 - same order
# ******************* Gomperts_2021 - same order
# ******************* Eils_2020 - same order
# ******************* Schiller_2020 - same order
# ******************* Misharin_Budinger_2018 - same order
# ******************* Shalek_2018 - same order
# ******************* Schiller_2021 - same order
# ******************* Peer_Massague_2020 - same order
# ******************* Lafyatis_2019 - same order
# ******************* Tata_unpubl - same order
# ******************* Xu_2020 - same order
# ******************* Sims_2019 - same order
# ******************* Schultze_unpubl - same order

# %% [markdown]
# Mannually selected some

# %%
check_after = [
    "ENSG00000122674.12_CCZ1",
    "ENSG00000114374.13_USP9Y",
    "ENSG00000099977.15_DDT",
]

# %% [markdown]
# Getting dataset sufixes

# %%
df = pd.crosstab(embed_obs["study"], embed_obs["core_or_extension"])
df
# Out:
# core_or_extension         core  extension
# study
# Banovich_Kropski_2020   121894      82692
# Barbry_Leroy_2020        74487          0
# Barbry_unpubl                0     100211
# Budinger_2020                0      91980
# Duong_lungMAP_unpubl         0      53904
# Eils_2020                    0      39778
# Gomperts_2021                0      40709
# Jain_Misharin_2021       45557          0
# Janssen_2020                 0      49384
# Kaminski_2020                0     307650
# Krasnow_2020             60982          0
# Lafyatis_2019                0      27297
# Lafyatis_Rojas_2019      24181          0
# Lambrechts_2021              0      65166
# Meyer_2019               35554          0
# Meyer_2021                   0     129340
# Meyer_Nikolic_2022           0     119634
# Misharin_2021            64843          0
# Misharin_Budinger_2018   41220      37097
# Nawijn_2021              70402          0
# Peer_Massague_2020           0      32850
# Regev_2021                   0      96060
# Schiller_2020                0      38648
# Schiller_2021                0      35984
# Schultze_unpubl              0       8016
# Seibold_2020             33593          0
# Shalek_2018                  0      36740
# Sheppard_2020                0      80020
# Sims_2019                    0      10790
# Sun_2020                     0      46500
# Tata_unpubl                  0      21700
# Teichmann_Meyer_2019     12231          0
# Thienpont_2018               0      93575
# Wunderink_2021               0      77146
# Xu_2020                      0      12374
# Zhang_2021                   0      62469

# %%
for ds_merged in adata_split.keys():
    print(f"\033[1m\033[93mChecking completeness:\033[0m {ds_merged}")
    ds_column = list(adata_split[ds_merged].keys())[0]
    temp = [re.sub(f"_{ds_merged}$", "", i) for i in adata_split[ds_merged][ds_column]]
    temp.extend(list(adatas.keys()))
    adata_presence = [i in temp for i in df.index]
    print(f"All in collected matrices? {all(adata_presence)}")
    if not all(adata_presence):
        print("Missing:")
        [i for i in df.index if not i in temp]
# Out:
# Checking completeness: HLCA
# All in collected matrices? True

# %% [markdown]
# Inspect for "dataset" from core and extension that share the same name.

# %%
embed_obs["study_coe"] = (
    embed_obs["study"].astype(str) + "-" + embed_obs["core_or_extension"].astype(str)
)

# %%
df = pd.crosstab(embed_obs["study_coe"], embed_obs["dataset"])
df["study"] = [re.sub("-.*", "", i) for i in df.index.tolist()]
df["core_or_extension"] = [re.sub(".*-", "", i) for i in df.index.tolist()]
df = df.melt(id_vars=["study", "core_or_extension"])
pd.set_option("display.max_rows", df.shape[0])
df = df.loc[df["value"].astype(int) > 0, :]
df
# Out:
#                        study core_or_extension                    dataset  \
# 0      Banovich_Kropski_2020              core      Banovich_Kropski_2020
# 1      Banovich_Kropski_2020         extension      Banovich_Kropski_2020
# 40         Barbry_Leroy_2020              core          Barbry_Leroy_2020
# 79             Barbry_unpubl         extension              Barbry_unpubl
# 118            Budinger_2020         extension              Budinger_2020
# 157     Duong_lungMAP_unpubl         extension       Duong_lungMAP_unpubl
# 196                Eils_2020         extension                  Eils_2020
# 235            Gomperts_2021         extension          Gomperts2021_UCLA
# 273            Gomperts_2021         extension          Gomperts_2021_CFF
# 311            Gomperts_2021         extension         Gomperts_2021_CSMC
# 350       Jain_Misharin_2021              core   Jain_Misharin_2021_10Xv1
# 388       Jain_Misharin_2021              core   Jain_Misharin_2021_10Xv2
# 427             Janssen_2020         extension               Janssen_2020
# 466            Kaminski_2020         extension              Kaminski_2020
# 505             Krasnow_2020              core               Krasnow_2020
# 544            Lafyatis_2019         extension              Lafyatis_2019
# 583      Lafyatis_Rojas_2019              core  Lafyatis_Rojas_2019_10Xv1
# 621      Lafyatis_Rojas_2019              core  Lafyatis_Rojas_2019_10Xv2
# 660          Lambrechts_2021         extension            Lambrechts_2021
# 701       Meyer_Nikolic_2022         extension    MeyerNikolic_unpubl_UCL
# 737               Meyer_2019              core                 Meyer_2019
# 776               Meyer_2021         extension          Meyer_2021_3prime
# 814               Meyer_2021         extension          Meyer_2021_5prime
# 854            Misharin_2021              core              Misharin_2021
# 893   Misharin_Budinger_2018              core     Misharin_Budinger_2018
# 894   Misharin_Budinger_2018         extension     Misharin_Budinger_2018
# 933              Nawijn_2021              core                Nawijn_2021
# 972       Peer_Massague_2020         extension         Peer_Massague_2020
# 1011              Regev_2021         extension            Regev_2021_Cryo
# 1049              Regev_2021         extension           Regev_2021_Fresh
# 1087              Regev_2021         extension          Regev_2021_Nuclei
# 1126           Schiller_2020         extension              Schiller_2020
# 1165           Schiller_2021         extension              Schiller_2021
# 1204         Schultze_unpubl         extension            Schultze_unpubl
# 1243            Seibold_2020              core         Seibold_2020_10Xv2
# 1281            Seibold_2020              core         Seibold_2020_10Xv3
# 1320             Shalek_2018         extension                Shalek_2018
# 1359           Sheppard_2020         extension              Sheppard_2020
# 1398               Sims_2019         extension                  Sims_2019
# 1437                Sun_2020         extension            Sun_2020_batch1
# 1475                Sun_2020         extension            Sun_2020_batch2
# 1513                Sun_2020         extension            Sun_2020_batch3
# 1551                Sun_2020         extension            Sun_2020_batch4
# 1590             Tata_unpubl         extension                Tata_unpubl
# 1629    Teichmann_Meyer_2019              core       Teichmann_Meyer_2019
# 1668          Thienpont_2018         extension       Thienpont_2018_10Xv1
# 1706          Thienpont_2018         extension       Thienpont_2018_10Xv2
# 1745          Wunderink_2021         extension        Wunderink_2021_cryo
# 1783          Wunderink_2021         extension       Wunderink_2021_fresh
# 1822                 Xu_2020         extension             Xu_2020_LAM1_3
# 1861              Zhang_2021         extension                 Zhang_2021
#
#        value
# 0     121894
# 1      82692
# 40     74487
# 79    100211
# 118    91980
# 157    53904
# 196    39778
# 235    19239
# 273     6995
# 311    14475
# 350    12422
# 388    33135
# 427    49384
# 466   307650
# 505    60982
# 544    27297
# 583     2921
# 621    21260
# 660    65166
# 701   119634
# 737    35554
# 776    24628
# 814   104712
# 854    64843
# 893    41220
# 894    37097
# 933    70402
# 972    32850
# 1011    4366
# 1049    2268
# 1087   89426
# 1126   38648
# 1165   35984
# 1204    8016
# 1243   12127
# 1281   21466
# 1320   36740
# 1359   80020
# 1398   10790
# 1437    5217
# 1475   10672
# 1513   13757
# 1551   16854
# 1590   21700
# 1629   12231
# 1668    4272
# 1706   89303
# 1745   51689
# 1783   25457
# 1822   12374
# 1861   62469

# %% [markdown]
# Separating datasets present in both core and extension

# %%
df["temp"] = df["study"] + df["dataset"]
dataset_repeated = df.loc[df["temp"].duplicated(), "study"].tolist()
del df["temp"]
df.loc[df["study"].isin(dataset_repeated), :]
# Out:
#                       study core_or_extension                 dataset   value
# 0     Banovich_Kropski_2020              core   Banovich_Kropski_2020  121894
# 1     Banovich_Kropski_2020         extension   Banovich_Kropski_2020   82692
# 893  Misharin_Budinger_2018              core  Misharin_Budinger_2018   41220
# 894  Misharin_Budinger_2018         extension  Misharin_Budinger_2018   37097

# %%
# %%time
temp = []
for i in embed_obs.index:
    ds_name = embed_obs.loc[i, "dataset"]
    if ds_name in dataset_repeated:
        temp.append(ds_name + "_" + embed_obs.loc[i, "core_or_extension"])
    else:
        temp.append(ds_name)
embed_obs["dataset_temp"] = temp
# Out:
# CPU times: user 28.2 s, sys: 20.4 ms, total: 28.2 s
# Wall time: 28.3 s

# %%
core_or_extension_column = [
    i for i, v in enumerate(embed_obs.columns) if v == "core_or_extension"
]
for ds in set(embed_obs["dataset_temp"].tolist()):
    df = embed_obs.loc[embed_obs["dataset_temp"].isin([ds]), :]
    temp = df.iloc[:, core_or_extension_column[0]].value_counts()
    temp = temp[temp > 0].index.tolist()
    if len(temp) > 1:
        print(f"\033[91m*******************\033[0m {ds}")
    else:
        print(f"\033[1m\033[92m*******************\033[0m {ds}")
    print(f"Study: {df.iloc[0, 3]} ({temp})")
    print(f"Barcode: '{df.index[0]}'")
# Out:
# ******************* Zhang_2021
# Study: Zhang_2021 (['extension'])
# Barcode: 'AAACCCACAGCTACAT_3_liao'
# ******************* Jain_Misharin_2021_10Xv2
# Study: Jain_Misharin_2021 (['core'])
# Barcode: 'GTAGTCACATGCCTAA-1-4'
# ******************* Wunderink_2021_fresh
# Study: Wunderink_2021 (['extension'])
# Barcode: 'AAACCTGAGAAACCGC-0_grant_fresh'
# ******************* Nawijn_2021
# Study: Nawijn_2021 (['core'])
# Barcode: 'CAGCCACAGTCACTA_GRO-03_biopsy'
# ******************* Meyer_2021_5prime
# Study: Meyer_2021 (['extension'])
# Barcode: 'AAACCTGAGACTAGGC-5841STDY7991475-0_meyer_unpubl'
# ******************* Gomperts2021_UCLA
# Study: Gomperts_2021 (['extension'])
# Barcode: 'BG9_2_AAAACGAGAGTT_carraro_ucla'
# ******************* Peer_Massague_2020
# Study: Peer_Massague_2020 (['extension'])
# Barcode: '0_laughney'
# ******************* Sheppard_2020
# Study: Sheppard_2020 (['extension'])
# Barcode: 'TCGTACCCATGATCCA_SCD1_tsukui'
# ******************* Teichmann_Meyer_2019
# Study: Teichmann_Meyer_2019 (['core'])
# Barcode: '7185212_CTGGTCTCACTGTTAG'
# ******************* Misharin_Budinger_2018_extension
# Study: Misharin_Budinger_2018 (['extension'])
# Barcode: 'SC30_AAACCTGCAACTGGCC_reyfman_disease'
# ******************* Thienpont_2018_10Xv2
# Study: Thienpont_2018 (['extension'])
# Barcode: 'BT1290_AAACCTGAGTAACCCT_lambrechts'
# ******************* Lafyatis_2019
# Study: Lafyatis_2019 (['extension'])
# Barcode: 'Valenzi_SSc1_AAACCTGAGCACCGTC_valenzi'
# ******************* Krasnow_2020
# Study: Krasnow_2020 (['core'])
# Barcode: 'P2_1_GCGCAACCAGTTAACC'
# ******************* Meyer_2019
# Study: Meyer_2019 (['core'])
# Barcode: 'GCTCCTAAGTGGACGT-1-HCATisStab7659969'
# ******************* Xu_2020_LAM1_3
# Study: Xu_2020 (['extension'])
# Barcode: 'AAACCTGAGCTGAAAT-1-LAM1-sub_guo'
# ******************* Banovich_Kropski_2020_extension
# Study: Banovich_Kropski_2020 (['extension'])
# Barcode: 'F00431_AAACCTGAGATCCGAG_haberman'
# ******************* Sun_2020_batch2
# Study: Sun_2020 (['extension'])
# Barcode: 'D046_AAAGTCCGTCCAAGAG-sub_wang_sub_batch2'
# ******************* Schultze_unpubl
# Study: Schultze_unpubl (['extension'])
# Barcode: 'Pool_350_AAAATATTTTCC_schultze_unpubl'
# ******************* Regev_2021_Fresh
# Study: Regev_2021 (['extension'])
# Barcode: '04-P103142-S148-R01-TACGGGCCACTTTAGG_delorey_fresh'
# ******************* Schiller_2021
# Study: Schiller_2021 (['extension'])
# Barcode: 'MUC24276_AAACCCAAGCGCCTCA-1_schiller_discovair'
# ******************* Sun_2020_batch4
# Study: Sun_2020 (['extension'])
# Barcode: 'D088_ACTTAGGTCGCTACGG-sub_wang_sub_batch4'
# ******************* Eils_2020
# Study: Eils_2020 (['extension'])
# Barcode: '101CV0ng_AAACCTGAGGTTCCTA-1_lukassen'
# ******************* Thienpont_2018_10Xv1
# Study: Thienpont_2018 (['extension'])
# Barcode: 'BT1238_AAATCAACTGCCTC_lambrechts'
# ******************* Schiller_2020
# Study: Schiller_2020 (['extension'])
# Barcode: 'muc10380_GAATTGCTCTTC_mayr'
# ******************* Barbry_unpubl
# Study: Barbry_unpubl (['extension'])
# Barcode: 'D463_BIOP_NAS1AAACCCAAGACATAGT-1-0_barbry'
# ******************* Barbry_Leroy_2020
# Study: Barbry_Leroy_2020 (['core'])
# Barcode: 'D363_Brus_Dis1_ATAAGAGAGCACCGTC-1-26'
# ******************* Jain_Misharin_2021_10Xv1
# Study: Jain_Misharin_2021 (['core'])
# Barcode: 'ATCACGACAACACCTA-1-1'
# ******************* Banovich_Kropski_2020_core
# Study: Banovich_Kropski_2020 (['core'])
# Barcode: 'GTCACGGAGACGCAAC_F02617'
# ******************* Seibold_2020_10Xv2
# Study: Seibold_2020 (['core'])
# Barcode: 'TAAGTGCCACTGTTAG_T121'
# ******************* Lafyatis_Rojas_2019_10Xv1
# Study: Lafyatis_Rojas_2019 (['core'])
# Barcode: 'ACCCACTGAACTGC-SC14'
# ******************* Kaminski_2020
# Study: Kaminski_2020 (['extension'])
# Barcode: '001C_AAACCTGCATCGGGTC_adams'
# ******************* Seibold_2020_10Xv3
# Study: Seibold_2020 (['core'])
# Barcode: 'CTTGATTGTCAGTTTG_T164'
# ******************* Shalek_2018
# Study: Shalek_2018 (['extension'])
# Barcode: 'Polyp1TOT_1_ordovasmontanes'
# ******************* Budinger_2020
# Study: Budinger_2020 (['extension'])
# Barcode: 'AAACCCACAAAGGTTA-10_bharat'
# ******************* Sun_2020_batch3
# Study: Sun_2020 (['extension'])
# Barcode: 'D032_AACAAGACAGCCCACA-sub_wang_sub_batch3'
# ******************* Sun_2020_batch1
# Study: Sun_2020 (['extension'])
# Barcode: 'D139_AAACCCAGTATCACGT-sub_wang_sub_batch1'
# ******************* Tata_unpubl
# Study: Tata_unpubl (['extension'])
# Barcode: 'AAACCCAAGGCTCCCA-1_DD046Q_tata_unpubl'
# ******************* Misharin_Budinger_2018_core
# Study: Misharin_Budinger_2018 (['core'])
# Barcode: 'GCGACCATCCCTAACC_SC22'
# ******************* Gomperts_2021_CFF
# Study: Gomperts_2021 (['extension'])
# Barcode: 'ND17494_AAAGAACGTCGCTGCA_carraro_cff'
# ******************* Gomperts_2021_CSMC
# Study: Gomperts_2021 (['extension'])
# Barcode: 'cc01p_AAACCTGCAATGGACG_carraro_csmc'
# ******************* Misharin_2021
# Study: Misharin_2021 (['core'])
# Barcode: 'TCATGAGGTCGCAGTC_SC142'
# ******************* Wunderink_2021_cryo
# Study: Wunderink_2021 (['extension'])
# Barcode: 'AAACCTGCAAAGGTGC-11_grant_cryo'
# ******************* Duong_lungMAP_unpubl
# Study: Duong_lungMAP_unpubl (['extension'])
# Barcode: 'LAP40_AAACCCAAGATGCTAA_duong'
# ******************* Janssen_2020
# Study: Janssen_2020 (['extension'])
# Barcode: 'AAACCCAAGCGTCTGC_1-PX1-sub_mould'
# ******************* Regev_2021_Nuclei
# Study: Regev_2021 (['extension'])
# Barcode: '02-P005175-S053-R01-GTTTGGAGTATCAAGA_delorey_nuclei'
# ******************* Lafyatis_Rojas_2019_10Xv2
# Study: Lafyatis_Rojas_2019 (['core'])
# Barcode: 'GACCAATGTGCTCTTC-SC156'
# ******************* Sims_2019
# Study: Sims_2019 (['extension'])
# Barcode: 'PP001nskept.CAAGATCTCTTGGGTA-0_szabo'
# ******************* MeyerNikolic_unpubl_UCL
# Study: Meyer_Nikolic_2022 (['extension'])
# Barcode: 'AAACCTGAGGAGTTGC-CV001_KM8853544-ucl_meyer_nikolic_unpubl'
# ******************* Lambrechts_2021
# Study: Lambrechts_2021 (['extension'])
# Barcode: 'BAL009_AAACCTGAGCTAGCCC-1_wouters'
# ******************* Regev_2021_Cryo
# Study: Regev_2021 (['extension'])
# Barcode: '02-P166169-S099-R01-TAACTTCGTGCACAAG_delorey_cryo'
# ******************* Meyer_2021_3prime
# Study: Meyer_2021 (['extension'])
# Barcode: 'AAACCTGGTGTGAATA-1-WTDAtest7887999-0_meyer_unpubl'

# %%
adata_dict_conversion = {
    "Meyer_2019": ["", "Meyer_2019"],
    "Janssen_2020": ["sub_mould", "Janssen_2020"],
    "Zhang_2021": ["liao", "Zhang_2021"],
    "Barbry_Leroy_2020": ["", "Barbry_Leroy_2020"],
    "Peer_Massague_2020": ["laughney", "Peer_Massague_2020"],
    "Jain_Misharin_2021_10Xv1": ["", "Jain_Misharin_2021"],
    "Eils_2020": ["lukassen", "Eils_2020"],
    "Sheppard_2020": ["tsukui", "Sheppard_2020"],
    "Shalek_2018": ["ordovasmontanes", "Shalek_2018"],
    "Misharin_Budinger_2018_extension": [
        "reyfman_disease",
        "Misharin_Budinger_2018",
    ],  # see above the one shown doesn't have 'reyfman_disease', I suspect it's the core vs extension difference
    "Misharin_Budinger_2018_core": [
        "",
        "Misharin_Budinger_2018",
    ],
    "Gomperts_2021_CFF": ["carraro_cff", "Gomperts_2021"],
    "Kaminski_2020": ["adams", "Kaminski_2020"],
    "Schiller_2021": ["schiller_discovair", "Schiller_2021"],
    "Gomperts_2021_CSMC": ["carraro_csmc", "Gomperts_2021"],
    "Lambrechts_2021": ["wouters", "Lambrechts_2021"],
    "Meyer_2021_3prime": ["meyer_unpubl", "Meyer_2021"],
    "Barbry_unpubl": ["barbry", "Barbry_unpubl"],
    "Sun_2020_batch3": ["sub_wang_sub_batch3", "Sun_2020"],
    "Regev_2021_Fresh": ["delorey_fresh", "Regev_2021"],
    "Thienpont_2018_10Xv2": ["lambrechts", "Thienpont_2018"],
    "Lafyatis_Rojas_2019_10Xv1": ["", "Lafyatis_Rojas_2019"],
    "Budinger_2020": ["bharat", "Budinger_2020"],
    "Krasnow_2020": ["", "Krasnow_2020"],
    "Sun_2020_batch4": ["sub_wang_sub_batch4", "Sun_2020"],
    "Meyer_2021_5prime": ["meyer_unpubl", "Meyer_2021"],
    "Schiller_2020": ["mayr", "Schiller_2020"],
    "Tata_unpubl": ["tata_unpubl", "Tata_unpubl"],
    "Gomperts2021_UCLA": ["carraro_ucla", "Gomperts_2021"],
    "Xu_2020_LAM1_3": ["sub_guo", "Xu_2020"],
    "Banovich_Kropski_2020_extension": [
        "haberman",
        "Banovich_Kropski_2020",
    ],  # see above the one shown doesn't have 'haberman', I suspect it's the core vs extension difference
    "Banovich_Kropski_2020_core": [
        "",
        "Banovich_Kropski_2020",
    ],
    "Seibold_2020_10Xv3": ["", "Seibold_2020"],
    "Regev_2021_Cryo": ["delorey_cryo", "Regev_2021"],
    "Wunderink_2021_fresh": ["grant_fresh", "Wunderink_2021"],
    "Sun_2020_batch1": ["sub_wang_sub_batch1", "Sun_2020"],
    "MeyerNikolic_unpubl_UCL": ["meyer_nikolic_unpubl", "Meyer_Nikolic_2022"],
    "Regev_2021_Nuclei": ["delorey_nuclei", "Regev_2021"],
    "Schultze_unpubl": ["schultze_unpubl", "Schultze_unpubl"],
    "Teichmann_Meyer_2019": ["", "Teichmann_Meyer_2019"],
    "Seibold_2020_10Xv2": ["", "Seibold_2020"],
    "Sun_2020_batch2": ["sub_wang_sub_batch2", "Sun_2020"],
    "Nawijn_2021": ["", "Nawijn_2021"],  # biopsy
    "Lafyatis_Rojas_2019_10Xv2": ["", "Lafyatis_Rojas_2019"],
    "Sims_2019": ["szabo", "Sims_2019"],
    "Misharin_2021": ["", "Misharin_2021"],
    "Jain_Misharin_2021_10Xv2": ["", "Jain_Misharin_2021"],
    "Lafyatis_2019": ["valenzi", "Lafyatis_2019"],
    "Thienpont_2018_10Xv1": ["lambrechts", "Thienpont_2018"],
    "Wunderink_2021_cryo": ["grant_cryo", "Wunderink_2021"],
    "Duong_lungMAP_unpubl": ["duong", "Duong_lungMAP_unpubl"],
}

# %% [markdown]
# We will will replace the sufixes for the study to be able to match the metadatas. We are using dataset.
#
# This approach is forcing the old barcodes to match the result of the new concatenation. I suspect it would've been easier to add the sufixes found in the embedding to the appropiate dataset. The good thing about not doing that is that we end up with a "standardised" barcode.

# %%
gc.collect()
# Out:
# 3826

# %%
cellnames_old = list()
cellnames_new = list()
for ds in set(embed_obs["dataset_temp"]):
    if ds in adata_dict_conversion.keys():
        print(f"\033[1m\033[92m*******************\033[0m {ds}")
        sufix_change = adata_dict_conversion[ds]  # inferred sufix
    else:
        print(f"\033[1m\033[91m*******************\033[0m {ds}")
        sufix_change = ["", ds]
    print(sufix_change)
    cellname_old = embed_obs.loc[embed_obs["dataset_temp"].isin([ds]), :].index.tolist()
    if sufix_change[0] == "re":  # modify barcode and add sufix
        cellname_new = [
            re.sub(sufix_change[1], sufix_change[2], i) + "_" + sufix_change[3]
            for i in cellname_old
        ]
    elif sufix_change[0] != "":  # replace old sufix
        cellname_new = [
            re.sub(
                "_" + sufix_change[0] + "|-" + sufix_change[0], "_" + sufix_change[1], i
            )
            for i in cellname_old
        ]
    else:  # add new sufix
        cellname_new = [i + "_" + sufix_change[1] for i in cellname_old]
    print(cellname_old[:3])
    print(cellname_new[:3])
    cellnames_old.extend(cellname_old)
    cellnames_new.extend(cellname_new)
# Out:
# ******************* Zhang_2021
# ['liao', 'Zhang_2021']
# ['AAACCCACAGCTACAT_3_liao', 'AAACCCATCCACGGGT_3_liao', 'AAACGAACAAACAGGC_3_liao']
# ['AAACCCACAGCTACAT_3_Zhang_2021', 'AAACCCATCCACGGGT_3_Zhang_2021', 'AAACGAACAAACAGGC_3_Zhang_2021']
# ******************* Jain_Misharin_2021_10Xv2
# ['', 'Jain_Misharin_2021']
# ['GTAGTCACATGCCTAA-1-4', 'AAGGTTCTCGTAGATC-1-6', 'TAAGAGACAGCATACT-1-6']
# ['GTAGTCACATGCCTAA-1-4_Jain_Misharin_2021', 'AAGGTTCTCGTAGATC-1-6_Jain_Misharin_2021', 'TAAGAGACAGCATACT-1-6_Jain_Misharin_2021']
# ******************* Wunderink_2021_fresh
# ['grant_fresh', 'Wunderink_2021']
# ['AAACCTGAGAAACCGC-0_grant_fresh', 'AAACCTGAGCGTTTAC-0_grant_fresh', 'AAACCTGCAACTGCGC-0_grant_fresh']
# ['AAACCTGAGAAACCGC-0_Wunderink_2021', 'AAACCTGAGCGTTTAC-0_Wunderink_2021', 'AAACCTGCAACTGCGC-0_Wunderink_2021']
# ******************* Nawijn_2021
# ['', 'Nawijn_2021']
# ['CAGCCACAGTCACTA_GRO-03_biopsy', 'TCAGGTAGTGGTGTA_GRO-10_biopsy', 'AGTCCGGTCTCCCTA_GRO-08_biopsy']
# ['CAGCCACAGTCACTA_GRO-03_biopsy_Nawijn_2021', 'TCAGGTAGTGGTGTA_GRO-10_biopsy_Nawijn_2021', 'AGTCCGGTCTCCCTA_GRO-08_biopsy_Nawijn_2021']
# ******************* Meyer_2021_5prime
# ['meyer_unpubl', 'Meyer_2021']
# ['AAACCTGAGACTAGGC-5841STDY7991475-0_meyer_unpubl', 'AAACCTGAGAGTACAT-5841STDY7991475-0_meyer_unpubl', 'AAACCTGAGCTACCTA-5841STDY7991475-0_meyer_unpubl']
# ['AAACCTGAGACTAGGC-5841STDY7991475-0_Meyer_2021', 'AAACCTGAGAGTACAT-5841STDY7991475-0_Meyer_2021', 'AAACCTGAGCTACCTA-5841STDY7991475-0_Meyer_2021']
# ******************* Gomperts2021_UCLA
# ['carraro_ucla', 'Gomperts_2021']
# ['BG9_2_AAAACGAGAGTT_carraro_ucla', 'BG9_2_AAACAATTGCGG_carraro_ucla', 'BG9_2_AAACCCTTTCCT_carraro_ucla']
# ['BG9_2_AAAACGAGAGTT_Gomperts_2021', 'BG9_2_AAACAATTGCGG_Gomperts_2021', 'BG9_2_AAACCCTTTCCT_Gomperts_2021']
# ******************* Peer_Massague_2020
# ['laughney', 'Peer_Massague_2020']
# ['0_laughney', '2_laughney', '3_laughney']
# ['0_Peer_Massague_2020', '2_Peer_Massague_2020', '3_Peer_Massague_2020']
# ******************* Sheppard_2020
# ['tsukui', 'Sheppard_2020']
# ['TCGTACCCATGATCCA_SCD1_tsukui', 'TGAGCATGTTGCCTCT_IPF3_tsukui', 'AACCATGGTGGTCCGT_IPF3_tsukui']
# ['TCGTACCCATGATCCA_SCD1_Sheppard_2020', 'TGAGCATGTTGCCTCT_IPF3_Sheppard_2020', 'AACCATGGTGGTCCGT_IPF3_Sheppard_2020']
# ******************* Teichmann_Meyer_2019
# ['', 'Teichmann_Meyer_2019']
# ['7185212_CTGGTCTCACTGTTAG', '7239217_CATGGCGGTAGAAGGA', '7185212_GCGGGTTCAAGAAGAG']
# ['7185212_CTGGTCTCACTGTTAG_Teichmann_Meyer_2019', '7239217_CATGGCGGTAGAAGGA_Teichmann_Meyer_2019', '7185212_GCGGGTTCAAGAAGAG_Teichmann_Meyer_2019']
# ******************* Misharin_Budinger_2018_extension
# ['reyfman_disease', 'Misharin_Budinger_2018']
# ['SC30_AAACCTGCAACTGGCC_reyfman_disease', 'SC30_AAACCTGCACAGACAG_reyfman_disease', 'SC30_AAACCTGCACGTGAGA_reyfman_disease']
# ['SC30_AAACCTGCAACTGGCC_Misharin_Budinger_2018', 'SC30_AAACCTGCACAGACAG_Misharin_Budinger_2018', 'SC30_AAACCTGCACGTGAGA_Misharin_Budinger_2018']
# ******************* Thienpont_2018_10Xv2
# ['lambrechts', 'Thienpont_2018']
# ['BT1290_AAACCTGAGTAACCCT_lambrechts', 'BT1290_AAACCTGCAACGATGG_lambrechts', 'BT1290_AAACCTGCATTAGCCA_lambrechts']
# ['BT1290_AAACCTGAGTAACCCT_Thienpont_2018', 'BT1290_AAACCTGCAACGATGG_Thienpont_2018', 'BT1290_AAACCTGCATTAGCCA_Thienpont_2018']
# ******************* Lafyatis_2019
# ['valenzi', 'Lafyatis_2019']
# ['Valenzi_SSc1_AAACCTGAGCACCGTC_valenzi', 'Valenzi_SSc1_AAACCTGAGGAGCGAG_valenzi', 'Valenzi_SSc1_AAACCTGAGTAAGTAC_valenzi']
# ['Valenzi_SSc1_AAACCTGAGCACCGTC_Lafyatis_2019', 'Valenzi_SSc1_AAACCTGAGGAGCGAG_Lafyatis_2019', 'Valenzi_SSc1_AAACCTGAGTAAGTAC_Lafyatis_2019']
# ******************* Krasnow_2020
# ['', 'Krasnow_2020']
# ['P2_1_GCGCAACCAGTTAACC', 'P2_8_TTAGGACGTTCAGGCC', 'P3_3_CCACTACTCATTGCGA']
# ['P2_1_GCGCAACCAGTTAACC_Krasnow_2020', 'P2_8_TTAGGACGTTCAGGCC_Krasnow_2020', 'P3_3_CCACTACTCATTGCGA_Krasnow_2020']
# ******************* Meyer_2019
# ['', 'Meyer_2019']
# ['GCTCCTAAGTGGACGT-1-HCATisStab7659969', 'TTTATGCAGTGTTAGA-1-HCATisStab7747198', 'GATGCTATCTCCAACC-1-HCATisStab7747198']
# ['GCTCCTAAGTGGACGT-1-HCATisStab7659969_Meyer_2019', 'TTTATGCAGTGTTAGA-1-HCATisStab7747198_Meyer_2019', 'GATGCTATCTCCAACC-1-HCATisStab7747198_Meyer_2019']
# ******************* Xu_2020_LAM1_3
# ['sub_guo', 'Xu_2020']
# ['AAACCTGAGCTGAAAT-1-LAM1-sub_guo', 'AAACCTGAGGCTCTTA-1-LAM1-sub_guo', 'AAACCTGAGTCGTACT-1-LAM1-sub_guo']
# ['AAACCTGAGCTGAAAT-1-LAM1_Xu_2020', 'AAACCTGAGGCTCTTA-1-LAM1_Xu_2020', 'AAACCTGAGTCGTACT-1-LAM1_Xu_2020']
# ******************* Banovich_Kropski_2020_extension
# ['haberman', 'Banovich_Kropski_2020']
# ['F00431_AAACCTGAGATCCGAG_haberman', 'F00431_AAACCTGAGTTTCCTT_haberman', 'F00431_AAACGGGTCTCGCTTG_haberman']
# ['F00431_AAACCTGAGATCCGAG_Banovich_Kropski_2020', 'F00431_AAACCTGAGTTTCCTT_Banovich_Kropski_2020', 'F00431_AAACGGGTCTCGCTTG_Banovich_Kropski_2020']
# ******************* Sun_2020_batch2
# ['sub_wang_sub_batch2', 'Sun_2020']
# ['D046_AAAGTCCGTCCAAGAG-sub_wang_sub_batch2', 'D046_AACCTTTAGGGCCAAT-sub_wang_sub_batch2', 'D046_AAGCCATAGTGTTCCA-sub_wang_sub_batch2']
# ['D046_AAAGTCCGTCCAAGAG_Sun_2020', 'D046_AACCTTTAGGGCCAAT_Sun_2020', 'D046_AAGCCATAGTGTTCCA_Sun_2020']
# ******************* Schultze_unpubl
# ['schultze_unpubl', 'Schultze_unpubl']
# ['Pool_350_AAAATATTTTCC_schultze_unpubl', 'Pool_350_AAAATCATACTT_schultze_unpubl', 'Pool_350_AAAATTCTCAGC_schultze_unpubl']
# ['Pool_350_AAAATATTTTCC_Schultze_unpubl', 'Pool_350_AAAATCATACTT_Schultze_unpubl', 'Pool_350_AAAATTCTCAGC_Schultze_unpubl']
# ******************* Regev_2021_Fresh
# ['delorey_fresh', 'Regev_2021']
# ['04-P103142-S148-R01-TACGGGCCACTTTAGG_delorey_fresh', '04-P103142-S148-R01-CAACAGTCAAACAGGC_delorey_fresh', '04-P103142-S148-R01-CCGTTCACAGGAGACT_delorey_fresh']
# ['04-P103142-S148-R01-TACGGGCCACTTTAGG_Regev_2021', '04-P103142-S148-R01-CAACAGTCAAACAGGC_Regev_2021', '04-P103142-S148-R01-CCGTTCACAGGAGACT_Regev_2021']
# ******************* Schiller_2021
# ['schiller_discovair', 'Schiller_2021']
# ['MUC24276_AAACCCAAGCGCCTCA-1_schiller_discovair', 'MUC24276_AAACCCAAGGCCCGTT-1_schiller_discovair', 'MUC24276_AAACCCAAGGTCCGAA-1_schiller_discovair']
# ['MUC24276_AAACCCAAGCGCCTCA-1_Schiller_2021', 'MUC24276_AAACCCAAGGCCCGTT-1_Schiller_2021', 'MUC24276_AAACCCAAGGTCCGAA-1_Schiller_2021']
# ******************* Sun_2020_batch4
# ['sub_wang_sub_batch4', 'Sun_2020']
# ['D088_ACTTAGGTCGCTACGG-sub_wang_sub_batch4', 'D231_AAACCCACAGAACTTC-sub_wang_sub_batch4', 'D231_AAACGAACAAAGTGTA-sub_wang_sub_batch4']
# ['D088_ACTTAGGTCGCTACGG_Sun_2020', 'D231_AAACCCACAGAACTTC_Sun_2020', 'D231_AAACGAACAAAGTGTA_Sun_2020']
# ******************* Eils_2020
# ['lukassen', 'Eils_2020']
# ['101CV0ng_AAACCTGAGGTTCCTA-1_lukassen', '101CV0ng_AAACCTGCAAGGCTCC-1_lukassen', '101CV0ng_AAACCTGCACGAAATA-1_lukassen']
# ['101CV0ng_AAACCTGAGGTTCCTA-1_Eils_2020', '101CV0ng_AAACCTGCAAGGCTCC-1_Eils_2020', '101CV0ng_AAACCTGCACGAAATA-1_Eils_2020']
# ******************* Thienpont_2018_10Xv1
# ['lambrechts', 'Thienpont_2018']
# ['BT1238_AAATCAACTGCCTC_lambrechts', 'BT1238_AACATTGACCTAAG_lambrechts', 'BT1238_AACCAGTGCTTAGG_lambrechts']
# ['BT1238_AAATCAACTGCCTC_Thienpont_2018', 'BT1238_AACATTGACCTAAG_Thienpont_2018', 'BT1238_AACCAGTGCTTAGG_Thienpont_2018']
# ******************* Schiller_2020
# ['mayr', 'Schiller_2020']
# ['muc10380_GAATTGCTCTTC_mayr', 'muc10380_TTTTTTCGCTCA_mayr', 'muc10380_ACTGTTTGGCAG_mayr']
# ['muc10380_GAATTGCTCTTC_Schiller_2020', 'muc10380_TTTTTTCGCTCA_Schiller_2020', 'muc10380_ACTGTTTGGCAG_Schiller_2020']
# ******************* Barbry_unpubl
# ['barbry', 'Barbry_unpubl']
# ['D463_BIOP_NAS1AAACCCAAGACATAGT-1-0_barbry', 'D463_BIOP_NAS1AAACCCAAGGGATCAC-1-0_barbry', 'D463_BIOP_NAS1AAACCCAAGTATGGCG-1-0_barbry']
# ['D463_BIOP_NAS1AAACCCAAGACATAGT-1-0_Barbry_unpubl', 'D463_BIOP_NAS1AAACCCAAGGGATCAC-1-0_Barbry_unpubl', 'D463_BIOP_NAS1AAACCCAAGTATGGCG-1-0_Barbry_unpubl']
# ******************* Barbry_Leroy_2020
# ['', 'Barbry_Leroy_2020']
# ['D363_Brus_Dis1_ATAAGAGAGCACCGTC-1-26', 'D372_Biop_Int2_CTGTTTAAGTCTTGCA-1-34', 'D326_Biop_Pro1_CTACACCTCGGCGCAT-1-3']
# ['D363_Brus_Dis1_ATAAGAGAGCACCGTC-1-26_Barbry_Leroy_2020', 'D372_Biop_Int2_CTGTTTAAGTCTTGCA-1-34_Barbry_Leroy_2020', 'D326_Biop_Pro1_CTACACCTCGGCGCAT-1-3_Barbry_Leroy_2020']
# ******************* Jain_Misharin_2021_10Xv1
# ['', 'Jain_Misharin_2021']
# ['ATCACGACAACACCTA-1-1', 'TATGCCCGTGACGCCT-1-2', 'ACTGAGTAGAGAACAG-1-2']
# ['ATCACGACAACACCTA-1-1_Jain_Misharin_2021', 'TATGCCCGTGACGCCT-1-2_Jain_Misharin_2021', 'ACTGAGTAGAGAACAG-1-2_Jain_Misharin_2021']
# ******************* Banovich_Kropski_2020_core
# ['', 'Banovich_Kropski_2020']
# ['GTCACGGAGACGCAAC_F02617', 'CGACTTCCATTCCTGC_HD68', 'ATTGGACAGCCGATTT_F02526']
# ['GTCACGGAGACGCAAC_F02617_Banovich_Kropski_2020', 'CGACTTCCATTCCTGC_HD68_Banovich_Kropski_2020', 'ATTGGACAGCCGATTT_F02526_Banovich_Kropski_2020']
# ******************* Seibold_2020_10Xv2
# ['', 'Seibold_2020']
# ['TAAGTGCCACTGTTAG_T121', 'AGTGGGATCTTGGGTA_T89', 'TAGGCATGTTGTCTTT_T137']
# ['TAAGTGCCACTGTTAG_T121_Seibold_2020', 'AGTGGGATCTTGGGTA_T89_Seibold_2020', 'TAGGCATGTTGTCTTT_T137_Seibold_2020']
# ******************* Lafyatis_Rojas_2019_10Xv1
# ['', 'Lafyatis_Rojas_2019']
# ['ACCCACTGAACTGC-SC14', 'TACGCCACGATGAA-SC14', 'GCCATGCTTCGTTT-SC14']
# ['ACCCACTGAACTGC-SC14_Lafyatis_Rojas_2019', 'TACGCCACGATGAA-SC14_Lafyatis_Rojas_2019', 'GCCATGCTTCGTTT-SC14_Lafyatis_Rojas_2019']
# ******************* Kaminski_2020
# ['adams', 'Kaminski_2020']
# ['001C_AAACCTGCATCGGGTC_adams', '001C_AAACCTGTCAACACCA_adams', '001C_AAACCTGTCACAGTAC_adams']
# ['001C_AAACCTGCATCGGGTC_Kaminski_2020', '001C_AAACCTGTCAACACCA_Kaminski_2020', '001C_AAACCTGTCACAGTAC_Kaminski_2020']
# ******************* Seibold_2020_10Xv3
# ['', 'Seibold_2020']
# ['CTTGATTGTCAGTTTG_T164', 'GGGAAGTAGCAGCGAT_T165', 'GCACGGTTCTAAGGAA_T154']
# ['CTTGATTGTCAGTTTG_T164_Seibold_2020', 'GGGAAGTAGCAGCGAT_T165_Seibold_2020', 'GCACGGTTCTAAGGAA_T154_Seibold_2020']
# ******************* Shalek_2018
# ['ordovasmontanes', 'Shalek_2018']
# ['Polyp1TOT_1_ordovasmontanes', 'Polyp1TOT_2_ordovasmontanes', 'Polyp1TOT_3_ordovasmontanes']
# ['Polyp1TOT_1_Shalek_2018', 'Polyp1TOT_2_Shalek_2018', 'Polyp1TOT_3_Shalek_2018']
# ******************* Budinger_2020
# ['bharat', 'Budinger_2020']
# ['AAACCCACAAAGGTTA-10_bharat', 'AAACCCACACGAGAAC-10_bharat', 'AAACCCACAGACGGAT-10_bharat']
# ['AAACCCACAAAGGTTA-10_Budinger_2020', 'AAACCCACACGAGAAC-10_Budinger_2020', 'AAACCCACAGACGGAT-10_Budinger_2020']
# ******************* Sun_2020_batch3
# ['sub_wang_sub_batch3', 'Sun_2020']
# ['D032_AACAAGACAGCCCACA-sub_wang_sub_batch3', 'D032_AACAGGGGTCCAGCGT-sub_wang_sub_batch3', 'D032_AACGAAAGTTCCATTT-sub_wang_sub_batch3']
# ['D032_AACAAGACAGCCCACA_Sun_2020', 'D032_AACAGGGGTCCAGCGT_Sun_2020', 'D032_AACGAAAGTTCCATTT_Sun_2020']
# ******************* Sun_2020_batch1
# ['sub_wang_sub_batch1', 'Sun_2020']
# ['D139_AAACCCAGTATCACGT-sub_wang_sub_batch1', 'D139_AAACCCATCGAGCACC-sub_wang_sub_batch1', 'D139_AAACGAAGTGGTCCCA-sub_wang_sub_batch1']
# ['D139_AAACCCAGTATCACGT_Sun_2020', 'D139_AAACCCATCGAGCACC_Sun_2020', 'D139_AAACGAAGTGGTCCCA_Sun_2020']
# ******************* Tata_unpubl
# ['tata_unpubl', 'Tata_unpubl']
# ['AAACCCAAGGCTCCCA-1_DD046Q_tata_unpubl', 'AAACCCAGTATCTCTT-1_DD046Q_tata_unpubl', 'AAACGAAGTGGTCTAT-1_DD046Q_tata_unpubl']
# ['AAACCCAAGGCTCCCA-1_DD046Q_Tata_unpubl', 'AAACCCAGTATCTCTT-1_DD046Q_Tata_unpubl', 'AAACGAAGTGGTCTAT-1_DD046Q_Tata_unpubl']
# ******************* Misharin_Budinger_2018_core
# ['', 'Misharin_Budinger_2018']
# ['GCGACCATCCCTAACC_SC22', 'GCTCTGTAGTGCTGCC_SC27', 'AGGGAGTAGCGTTTAC_SC18']
# ['GCGACCATCCCTAACC_SC22_Misharin_Budinger_2018', 'GCTCTGTAGTGCTGCC_SC27_Misharin_Budinger_2018', 'AGGGAGTAGCGTTTAC_SC18_Misharin_Budinger_2018']
# ******************* Gomperts_2021_CFF
# ['carraro_cff', 'Gomperts_2021']
# ['ND17494_AAAGAACGTCGCTGCA_carraro_cff', 'ND17494_AAAGAACGTTGCAACT_carraro_cff', 'ND17494_AAAGGGCGTTTACGTG_carraro_cff']
# ['ND17494_AAAGAACGTCGCTGCA_Gomperts_2021', 'ND17494_AAAGAACGTTGCAACT_Gomperts_2021', 'ND17494_AAAGGGCGTTTACGTG_Gomperts_2021']
# ******************* Gomperts_2021_CSMC
# ['carraro_csmc', 'Gomperts_2021']
# ['cc01p_AAACCTGCAATGGACG_carraro_csmc', 'cc01p_AAACCTGGTCTGCCAG_carraro_csmc', 'cc01p_AAACGGGAGCTTTGGT_carraro_csmc']
# ['cc01p_AAACCTGCAATGGACG_Gomperts_2021', 'cc01p_AAACCTGGTCTGCCAG_Gomperts_2021', 'cc01p_AAACGGGAGCTTTGGT_Gomperts_2021']
# ******************* Misharin_2021
# ['', 'Misharin_2021']
# ['TCATGAGGTCGCAGTC_SC142', 'TCTTCCTTCTTGGATG_SC141', 'ACGGTTACAGTCTTCC_SC84']
# ['TCATGAGGTCGCAGTC_SC142_Misharin_2021', 'TCTTCCTTCTTGGATG_SC141_Misharin_2021', 'ACGGTTACAGTCTTCC_SC84_Misharin_2021']
# ******************* Wunderink_2021_cryo
# ['grant_cryo', 'Wunderink_2021']
# ['AAACCTGCAAAGGTGC-11_grant_cryo', 'AAACCTGCAGCCTTGG-11_grant_cryo', 'AAACCTGGTCGGCTCA-11_grant_cryo']
# ['AAACCTGCAAAGGTGC-11_Wunderink_2021', 'AAACCTGCAGCCTTGG-11_Wunderink_2021', 'AAACCTGGTCGGCTCA-11_Wunderink_2021']
# ******************* Duong_lungMAP_unpubl
# ['duong', 'Duong_lungMAP_unpubl']
# ['LAP40_AAACCCAAGATGCTAA_duong', 'LAP40_AAACCCAAGATTGACA_duong', 'LAP40_AAACCCAGTTTCTATC_duong']
# ['LAP40_AAACCCAAGATGCTAA_Duong_lungMAP_unpubl', 'LAP40_AAACCCAAGATTGACA_Duong_lungMAP_unpubl', 'LAP40_AAACCCAGTTTCTATC_Duong_lungMAP_unpubl']
# ******************* Janssen_2020
# ['sub_mould', 'Janssen_2020']
# ['AAACCCAAGCGTCTGC_1-PX1-sub_mould', 'AAACCCAAGTGATAAC_1-PX1-sub_mould', 'AAACCCAAGTTCCAGT_1-PX1-sub_mould']
# ['AAACCCAAGCGTCTGC_1-PX1_Janssen_2020', 'AAACCCAAGTGATAAC_1-PX1_Janssen_2020', 'AAACCCAAGTTCCAGT_1-PX1_Janssen_2020']
# ******************* Regev_2021_Nuclei
# ['delorey_nuclei', 'Regev_2021']
# ['02-P005175-S053-R01-GTTTGGAGTATCAAGA_delorey_nuclei', '02-P005175-S053-R01-TGCAGTAAGCAGATAT_delorey_nuclei', '02-P005175-S053-R01-CCCTAACCACTACCGG_delorey_nuclei']
# ['02-P005175-S053-R01-GTTTGGAGTATCAAGA_Regev_2021', '02-P005175-S053-R01-TGCAGTAAGCAGATAT_Regev_2021', '02-P005175-S053-R01-CCCTAACCACTACCGG_Regev_2021']
# ******************* Lafyatis_Rojas_2019_10Xv2
# ['', 'Lafyatis_Rojas_2019']
# ['GACCAATGTGCTCTTC-SC156', 'CTGATCCTCGTGGGAA-SC45', 'GCCAAATCAAAGGCGT-SC56']
# ['GACCAATGTGCTCTTC-SC156_Lafyatis_Rojas_2019', 'CTGATCCTCGTGGGAA-SC45_Lafyatis_Rojas_2019', 'GCCAAATCAAAGGCGT-SC56_Lafyatis_Rojas_2019']
# ******************* Sims_2019
# ['szabo', 'Sims_2019']
# ['PP001nskept.CAAGATCTCTTGGGTA-0_szabo', 'PP001nskept.CATCCACGTCACCTAA-0_szabo', 'PP001nskept.TTGAACGCACTAAGTC-0_szabo']
# ['PP001nskept.CAAGATCTCTTGGGTA-0_Sims_2019', 'PP001nskept.CATCCACGTCACCTAA-0_Sims_2019', 'PP001nskept.TTGAACGCACTAAGTC-0_Sims_2019']
# ******************* MeyerNikolic_unpubl_UCL
# ['meyer_nikolic_unpubl', 'Meyer_Nikolic_2022']
# ['AAACCTGAGGAGTTGC-CV001_KM8853544-ucl_meyer_nikolic_unpubl', 'AAACCTGAGTGGGCTA-CV001_KM8853544-ucl_meyer_nikolic_unpubl', 'AAACCTGCAAAGGCGT-CV001_KM8853544-ucl_meyer_nikolic_unpubl']
# ['AAACCTGAGGAGTTGC-CV001_KM8853544-ucl_Meyer_Nikolic_2022', 'AAACCTGAGTGGGCTA-CV001_KM8853544-ucl_Meyer_Nikolic_2022', 'AAACCTGCAAAGGCGT-CV001_KM8853544-ucl_Meyer_Nikolic_2022']
# ******************* Lambrechts_2021
# ['wouters', 'Lambrechts_2021']
# ['BAL009_AAACCTGAGCTAGCCC-1_wouters', 'BAL009_AAACCTGTCACATACG-1_wouters', 'BAL009_AAACGGGAGGGCTTCC-1_wouters']
# ['BAL009_AAACCTGAGCTAGCCC-1_Lambrechts_2021', 'BAL009_AAACCTGTCACATACG-1_Lambrechts_2021', 'BAL009_AAACGGGAGGGCTTCC-1_Lambrechts_2021']
# ******************* Regev_2021_Cryo
# ['delorey_cryo', 'Regev_2021']
# ['02-P166169-S099-R01-TAACTTCGTGCACAAG_delorey_cryo', '02-P166169-S099-R01-TGGGCGTAGTAGCCAG_delorey_cryo', '02-P166169-S099-R01-GTGCTTCTCCTCTTTC_delorey_cryo']
# ['02-P166169-S099-R01-TAACTTCGTGCACAAG_Regev_2021', '02-P166169-S099-R01-TGGGCGTAGTAGCCAG_Regev_2021', '02-P166169-S099-R01-GTGCTTCTCCTCTTTC_Regev_2021']
# ******************* Meyer_2021_3prime
# ['meyer_unpubl', 'Meyer_2021']
# ['AAACCTGGTGTGAATA-1-WTDAtest7887999-0_meyer_unpubl', 'AAACGGGCAACCGCCA-1-WTDAtest7887999-0_meyer_unpubl', 'AACCATGGTACAGCAG-1-WTDAtest7887999-0_meyer_unpubl']
# ['AAACCTGGTGTGAATA-1-WTDAtest7887999-0_Meyer_2021', 'AAACGGGCAACCGCCA-1-WTDAtest7887999-0_Meyer_2021', 'AACCATGGTACAGCAG-1-WTDAtest7887999-0_Meyer_2021']

# %% [markdown]
# Check if repeated indexes are introduced

# %%
temp = [k for k, v in Counter(cellnames_new).items() if v > 1]
temp
temp = [k for k, v in Counter(cellnames_old).items() if v > 1]
temp
# Out:
# []

# %%
print(len(cellnames_new), embed_obs.shape[0])
# Out:
# 2382658 2382658

# %%
df_cellnames = pd.DataFrame(index=cellnames_old)
df_cellnames["old"] = cellnames_old
df_cellnames["new"] = cellnames_new
df_cellnames["study"] = embed_obs.loc[df_cellnames["old"], "study"]

# %%
df_cellnames
# Out:
#                                                                                                  old  \
# AAACCCACAGCTACAT_3_liao                                                      AAACCCACAGCTACAT_3_liao
# AAACCCATCCACGGGT_3_liao                                                      AAACCCATCCACGGGT_3_liao
# AAACGAACAAACAGGC_3_liao                                                      AAACGAACAAACAGGC_3_liao
# AAACGAAGTCGCACAC_3_liao                                                      AAACGAAGTCGCACAC_3_liao
# AAACGAAGTGTAGTGG_3_liao                                                      AAACGAAGTGTAGTGG_3_liao
# ...                                                                                              ...
# TTTGTCAGTACCATCA-1-WTDAtest7732270-0_meyer_unpubl  TTTGTCAGTACCATCA-1-WTDAtest7732270-0_meyer_unpubl
# TTTGTCAGTAGCCTCG-1-WTDAtest7732270-0_meyer_unpubl  TTTGTCAGTAGCCTCG-1-WTDAtest7732270-0_meyer_unpubl
# TTTGTCAGTTAAGACA-1-WTDAtest7732270-0_meyer_unpubl  TTTGTCAGTTAAGACA-1-WTDAtest7732270-0_meyer_unpubl
# TTTGTCATCACCATAG-1-WTDAtest7732270-0_meyer_unpubl  TTTGTCATCACCATAG-1-WTDAtest7732270-0_meyer_unpubl
# TTTGTCATCCAACCAA-1-WTDAtest7732270-0_meyer_unpubl  TTTGTCATCCAACCAA-1-WTDAtest7732270-0_meyer_unpubl
#
#                                                                                                new  \
# AAACCCACAGCTACAT_3_liao                                              AAACCCACAGCTACAT_3_Zhang_2021
# AAACCCATCCACGGGT_3_liao                                              AAACCCATCCACGGGT_3_Zhang_2021
# AAACGAACAAACAGGC_3_liao                                              AAACGAACAAACAGGC_3_Zhang_2021
# AAACGAAGTCGCACAC_3_liao                                              AAACGAAGTCGCACAC_3_Zhang_2021
# AAACGAAGTGTAGTGG_3_liao                                              AAACGAAGTGTAGTGG_3_Zhang_2021
# ...                                                                                            ...
# TTTGTCAGTACCATCA-1-WTDAtest7732270-0_meyer_unpubl  TTTGTCAGTACCATCA-1-WTDAtest7732270-0_Meyer_2021
# TTTGTCAGTAGCCTCG-1-WTDAtest7732270-0_meyer_unpubl  TTTGTCAGTAGCCTCG-1-WTDAtest7732270-0_Meyer_2021
# TTTGTCAGTTAAGACA-1-WTDAtest7732270-0_meyer_unpubl  TTTGTCAGTTAAGACA-1-WTDAtest7732270-0_Meyer_2021
# TTTGTCATCACCATAG-1-WTDAtest7732270-0_meyer_unpubl  TTTGTCATCACCATAG-1-WTDAtest7732270-0_Meyer_2021
# TTTGTCATCCAACCAA-1-WTDAtest7732270-0_meyer_unpubl  TTTGTCATCCAACCAA-1-WTDAtest7732270-0_Meyer_2021
#
#                                                         study
# AAACCCACAGCTACAT_3_liao                            Zhang_2021
# AAACCCATCCACGGGT_3_liao                            Zhang_2021
# AAACGAACAAACAGGC_3_liao                            Zhang_2021
# AAACGAAGTCGCACAC_3_liao                            Zhang_2021
# AAACGAAGTGTAGTGG_3_liao                            Zhang_2021
# ...                                                       ...
# TTTGTCAGTACCATCA-1-WTDAtest7732270-0_meyer_unpubl  Meyer_2021
# TTTGTCAGTAGCCTCG-1-WTDAtest7732270-0_meyer_unpubl  Meyer_2021
# TTTGTCAGTTAAGACA-1-WTDAtest7732270-0_meyer_unpubl  Meyer_2021
# TTTGTCATCACCATAG-1-WTDAtest7732270-0_meyer_unpubl  Meyer_2021
# TTTGTCATCCAACCAA-1-WTDAtest7732270-0_meyer_unpubl  Meyer_2021
#
# [2382658 rows x 3 columns]

# %% [markdown]
# ### Main <a class="anchor" id="bullet4"></a>

# %% [markdown]
# We can now replace the genes.

# %%
gc.collect()
# Out:
# 1823

# %%
check_before_after = [
    ("SPP1", "SPP1"),  # ENSG00000118785.15_
    ("TREM2", "TREM2"),  # ENSG00000095970.17_
    ("FABP4", "FABP4"),  # ENSG00000170323.9_
]

# %%
# %%time
query_adatas = dict()
ds_list = np.array(list(adatas.keys()))
for ds in ds_list:
    print(f"\033[1;94m*******************\033[0m {ds} {np.where(ds_list == ds)[0][0]}/{len(ds_list)}")
    print(f"\033[0;33mMatrix:\033[0m {adatas[ds].shape} ", end="")
    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
    feats_df = feature_conversion[ds].copy().set_index("original", drop=False)
    if not ds in query_adatas.keys():
        features_rept = feats_df.loc[feats_df["repeat"], "original"].tolist()
        x_raw = pd.DataFrame(
            adatas[ds][:,features_rept].X.A.T,
            columns=adatas[ds].obs_names,
            index=features_rept,
        )
        x_raw["gene_new"] = feats_df.loc[feats_df["repeat"], "new"].tolist()
        x_raw_summed = x_raw.groupby("gene_new").sum()
        print(f"\033[1;33mRepeated features\033[0m {x_raw.shape[0]} => {x_raw_summed.shape[0]}")
        if ds == "Wunderink_2021" and x_raw_summed.shape[1] < 500:
            print(f"-------- \033[1m\033[91mBefore\033[0m")
            check_previ = x_raw.loc[x_raw["gene_new"].isin(check_after), :].index
            temp = x_raw.loc[
                check_previ,
            ]
            ds_cells = (temp != 0).any().index.tolist()
            ds_cells.append("sum")
            ds_cells = ds_cells[-5:]
            x_raw["sum"] = x_raw.sum(axis=1)
            print(x_raw.loc[check_previ, ds_cells])
            ds_cells.remove("gene_new")
            x_raw_summed["sum"] = x_raw_summed.sum(axis=1)
            print(f"-------- \033[1m\033[92mAfter\033[0m")
            print(x_raw_summed.loc[check_after, ds_cells])
        else:
            del x_raw
        query_adatas[ds] = ad.AnnData(X=x_raw_summed.T, obs=adatas[ds].obs)
        # Let's temporarily take the old names, so it's easy to replace them
        # when we have the full matrix, since the concatenation will have the old names
        temp = (
            feats_df
            .loc[feats_df["new"].isin(query_adatas[ds].var_names), :]
            .drop_duplicates(subset=["new"])
            .set_index("new")
        )
        query_adatas[ds].var = pd.DataFrame(index=temp.loc[query_adatas[ds].var_names,"original"].tolist())
        query_adatas[ds] = query_adatas[ds].T # we need to concatenate it var-wise
        features_uniq = (
            feats_df.loc[~feats_df["repeat"], "original"].tolist()
        )
        query_adatas[ds] = query_adatas[ds].concatenate(adatas[ds][:,features_uniq].copy().T, index_unique=None)
        query_adatas[ds] = query_adatas[ds].T # put vars back to the columns
        # Finishing
        cellname = adatas[ds].obs_names.tolist()
        query_adatas[ds] = query_adatas[ds][cellname]
        query_adatas[ds].obs = pd.DataFrame(index=cellname)
        query_adatas[ds].obs["cellname"] = cellname
        query_adatas[ds].obs["study"] = ds
        if query_adatas[ds].shape[0] < 100000:
            temp = [i for i, j in check_before_after if i in adatas[ds].var_names]
            if len(temp) > 0:
                print(temp)
                print(adatas[ds][:, temp].X.sum(axis=0))
            temp = [i for i, j in check_before_after if i in query_adatas[ds].var_names]
            if len(temp) > 0:
                print(temp)
                print(query_adatas[ds][:, temp].X.sum(axis=0))
        # Taking the new names
        query_adatas[ds].var = pd.DataFrame(
            index=feats_df.loc[query_adatas[ds].var_names, "new"].tolist()
        )
        if query_adatas[ds].shape[0] < 100000:
            temp = [j for i, j in check_before_after if j in query_adatas[ds].var_names]
            if len(temp) > 0:
                print(temp)
                print(query_adatas[ds][:, temp].X.sum(axis=0))
        gc.collect()
    print(f"\033[0;33mFinal\033[0m {query_adatas[ds].shape}")
# Out:
# ******************* Lafyatis_Rojas_2019_HLCA 0/38
# Matrix: (24181, 28527) 2023-02-07 21:49:03
# Repeated features 778 => 359
# ['SPP1', 'TREM2', 'FABP4']
# [[ 17730.  14560. 337551.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[ 17730.  14560. 337551.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[ 17730.  14560. 337551.]]
# Final (24181, 28108)
# ******************* Banovich_Kropski_2020_HLCA 1/38
# Matrix: (121894, 28527) 2023-02-07 21:49:07
# Repeated features 778 => 359
# Final (121894, 28108)
# ******************* Nawijn_2021_HLCA 2/38
# Matrix: (70402, 28527) 2023-02-07 21:49:20
# Repeated features 778 => 359
# ['SPP1', 'TREM2', 'FABP4']
# [[3818. 1902. 7741.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[3818. 1902. 7741.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[3818. 1902. 7741.]]
# Final (70402, 28108)
# ******************* Seibold_2020_HLCA 3/38
# Matrix: (33593, 28527) 2023-02-07 21:49:31
# Repeated features 778 => 359
# ['SPP1', 'TREM2', 'FABP4']
# [[1220. 5500.  336.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[1220. 5500.  336.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[1220. 5500.  336.]]
# Final (33593, 28108)
# ******************* Misharin_2021_HLCA 4/38
# Matrix: (64843, 28527) 2023-02-07 21:49:44
# Repeated features 778 => 359
# ['SPP1', 'TREM2', 'FABP4']
# [[  40500.   34504. 1229189.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[  40500.   34504. 1229189.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[  40500.   34504. 1229189.]]
# Final (64843, 28108)
# ******************* Teichmann_Meyer_2019_HLCA 5/38
# Matrix: (12231, 28527) 2023-02-07 21:49:56
# Repeated features 778 => 359
# ['SPP1', 'TREM2', 'FABP4']
# [[ 31882.   9342. 139456.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[ 31882.   9342. 139456.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[ 31882.   9342. 139456.]]
# Final (12231, 28108)
# ******************* Jain_Misharin_2021_HLCA 6/38
# Matrix: (45557, 28527) 2023-02-07 21:49:58
# Repeated features 778 => 359
# ['SPP1', 'TREM2', 'FABP4']
# [[ 11. 135.  46.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[ 11. 135.  46.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[ 11. 135.  46.]]
# Final (45557, 28108)
# ******************* Meyer_2019_HLCA 7/38
# Matrix: (35554, 28527) 2023-02-07 21:50:04
# Repeated features 778 => 359
# ['SPP1', 'TREM2', 'FABP4']
# [[21440. 10534. 88442.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[21440. 10534. 88442.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[21440. 10534. 88442.]]
# Final (35554, 28108)
# ******************* Barbry_Leroy_2020_HLCA 8/38
# Matrix: (74487, 28527) 2023-02-07 21:50:08
# Repeated features 778 => 359
# ['SPP1', 'TREM2', 'FABP4']
# [[ 2629.  2687. 83991.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[ 2629.  2687. 83991.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[ 2629.  2687. 83991.]]
# Final (74487, 28108)
# ******************* Krasnow_2020_HLCA 9/38
# Matrix: (60982, 28527) 2023-02-07 21:50:18
# Repeated features 778 => 359
# ['SPP1', 'TREM2', 'FABP4']
# [[   3282.   46679. 1680888.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[   3282.   46679. 1680888.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[   3282.   46679. 1680888.]]
# Final (60982, 28108)
# ******************* Misharin_Budinger_2018_HLCA 10/38
# Matrix: (41220, 28527) 2023-02-07 21:50:27
# Repeated features 778 => 359
# ['SPP1', 'TREM2', 'FABP4']
# [[  6134.  17940. 320375.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[  6134.  17940. 320375.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[  6134.  17940. 320375.]]
# Final (41220, 28108)
# ******************* Kaminski_2020 11/38
# Matrix: (307650, 45947) 2023-02-07 21:50:34
# Repeated features 1139 => 487
# Final (307650, 45295)
# ******************* Meyer_2021 12/38
# Matrix: (129340, 20922) 2023-02-07 21:51:35
# Repeated features 165 => 69
# Final (129340, 20826)
# ******************* Meyer_Nikolic_2022 13/38
# Matrix: (236977, 33582) 2023-02-07 21:51:47
# Repeated features 1460 => 675
# Final (236977, 32797)
# ******************* Barbry_unpubl 14/38
# Matrix: (100211, 16859) 2023-02-07 21:52:30
# Repeated features 187 => 90
# Final (100211, 16762)
# ******************* Regev_2021 15/38
# Matrix: (96060, 30983) 2023-02-07 21:53:02
# Repeated features 1134 => 529
# ['SPP1', 'TREM2', 'FABP4']
# [[19423.  1738.  6684.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[19423.  1738.  6684.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[19423.  1738.  6684.]]
# Final (96060, 30378)
# ******************* Thienpont_2018 16/38
# Matrix: (93575, 27958) 2023-02-07 21:53:14
# Repeated features 681 => 313
# ['SPP1', 'TREM2', 'FABP4']
# [[803721.  35531. 231595.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[803721.  35531. 231595.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[803721.  35531. 231595.]]
# Final (93575, 27590)
# ******************* Budinger_2020 17/38
# Matrix: (91980, 26316) 2023-02-07 21:53:23
# Repeated features 761 => 351
# ['SPP1', 'TREM2', 'FABP4']
# [[355852.  31173.  77978.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[355852.  31173.  77978.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[355852.  31173.  77978.]]
# Final (91980, 25906)
# ******************* Banovich_Kropski_2020 18/38
# Matrix: (82692, 33694) 2023-02-07 21:53:35
# Repeated features 1143 => 530
# ['SPP1', 'TREM2', 'FABP4']
# [[479525.  97635. 882027.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[479525.  97635. 882027.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[479525.  97635. 882027.]]
# Final (82692, 33081)
# ******************* Sheppard_2020 19/38
# Matrix: (80020, 27147) 2023-02-07 21:53:52
# Repeated features 705 => 326
# ['SPP1', 'TREM2', 'FABP4']
# [[272495.  21517. 172011.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[272495.  21517. 172011.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[272495.  21517. 172011.]]
# Final (80020, 26768)
# ******************* Wunderink_2021 20/38
# Matrix: (77146, 21819) 2023-02-07 21:54:01
# Repeated features 517 => 237
# ['SPP1', 'TREM2', 'FABP4']
# [[226068.  69852. 193290.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[226068.  69852. 193290.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[226068.  69852. 193290.]]
# Final (77146, 21539)
# ******************* Lambrechts_2021 21/38
# Matrix: (65166, 33538) 2023-02-07 21:54:12
# Repeated features 1442 => 675
# ['SPP1', 'TREM2', 'FABP4']
# [[ 96572.  26798. 236328.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[ 96572.  26798. 236328.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[ 96572.  26798. 236328.]]
# Final (65166, 32771)
# ******************* Zhang_2021 22/38
# Matrix: (62469, 18474) 2023-02-07 21:54:18
# Repeated features 95 => 36
# ['SPP1', 'TREM2', 'FABP4']
# [[375268.  58298. 618248.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[375268.  58298. 618248.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[375268.  58298. 618248.]]
# Final (62469, 18415)
# ******************* Duong_lungMAP_unpubl 23/38
# Matrix: (53904, 27678) 2023-02-07 21:54:25
# Repeated features 841 => 395
# ['SPP1', 'TREM2', 'FABP4']
# [[ 194.  198. 4765.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[ 194.  198. 4765.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[ 194.  198. 4765.]]
# Final (53904, 27232)
# ******************* Janssen_2020 24/38
# Matrix: (49384, 33538) 2023-02-07 21:54:34
# Repeated features 1442 => 675
# ['SPP1', 'TREM2', 'FABP4']
# [[   6622.  131247. 4754365.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[   6622.  131247. 4754365.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[   6622.  131247. 4754365.]]
# Final (49384, 32771)
# ******************* Sun_2020 25/38
# Matrix: (46500, 26578) 2023-02-07 21:54:47
# Repeated features 716 => 333
# ['SPP1', 'TREM2', 'FABP4']
# [[10734.  1081.  8782.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[10734.  1081.  8782.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[10734.  1081.  8782.]]
# Final (46500, 26195)
# ******************* Gomperts_2021 26/38
# Matrix: (40709, 31229) 2023-02-07 21:54:53
# Repeated features 9596 => 4581
# ['SPP1', 'TREM2', 'FABP4']
# [[ 304. 1156.   28.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[ 304. 1156.   28.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[ 304. 1156.   28.]]
# Final (40709, 26214)
# ******************* Eils_2020 27/38
# Matrix: (39778, 32738) 2023-02-07 21:55:07
# Repeated features 1609 => 752
# ['SPP1', 'TREM2', 'FABP4']
# [[ 1155.99998364  3207.00000773 21194.00001944]]
# ['SPP1', 'TREM2', 'FABP4']
# [[ 1156.  3207. 21194.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[ 1156.  3207. 21194.]]
# Final (39778, 31881)
# ******************* Schiller_2020 28/38
# Matrix: (38648, 32104) 2023-02-07 21:55:15
# Repeated features 6956 => 3394
# ['SPP1', 'TREM2', 'FABP4']
# [[ 2521.  1303. 14904.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[ 2521.  1303. 14904.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[ 2521.  1303. 14904.]]
# Final (38648, 28542)
# ******************* Misharin_Budinger_2018 29/38
# Matrix: (37097, 27181) 2023-02-07 21:55:24
# Repeated features 680 => 313
# ['SPP1', 'TREM2', 'FABP4']
# [[128995.  37293. 285988.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[128995.  37293. 285988.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[128995.  37293. 285988.]]
# Final (37097, 26814)
# ******************* Shalek_2018 30/38
# Matrix: (36740, 25328) 2023-02-07 21:55:29
# Repeated features 725 => 342
# ['SPP1', 'TREM2']
# [[1576.  586.]]
# ['SPP1', 'TREM2']
# [[1576.  586.]]
# ['SPP1', 'TREM2']
# [[1576.  586.]]
# Final (36740, 24945)
# ******************* Schiller_2021 31/38
# Matrix: (35984, 17533) 2023-02-07 21:55:31
# Repeated features 146 => 72
# ['SPP1', 'TREM2', 'FABP4']
# [[  6887.  24199. 419970.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[  6887.  24199. 419970.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[  6887.  24199. 419970.]]
# Final (35984, 17459)
# ******************* Peer_Massague_2020 32/38
# Matrix: (32850, 19222) 2023-02-07 21:55:36
# Repeated features 227 => 100
# ['SPP1', 'TREM2', 'FABP4']
# [[111365.  22748. 327554.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[111365.  22748. 327554.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[111365.  22748. 327554.]]
# Final (32850, 19095)
# ******************* Lafyatis_2019 33/38
# Matrix: (27297, 22164) 2023-02-07 21:55:39
# Repeated features 213 => 92
# ['SPP1', 'TREM2', 'FABP4']
# [[113586.  34936. 269949.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[113586.  34936. 269949.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[113586.  34936. 269949.]]
# Final (27297, 22043)
# ******************* Tata_unpubl 34/38
# Matrix: (21700, 31915) 2023-02-07 21:55:42
# Repeated features 744 => 352
# ['SPP1', 'TREM2', 'FABP4']
# [[15507.  4467. 59917.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[15507.  4467. 59917.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[15507.  4467. 59917.]]
# Final (21700, 31523)
# ******************* Xu_2020 35/38
# Matrix: (12374, 32738) 2023-02-07 21:55:47
# Repeated features 1609 => 752
# ['SPP1', 'TREM2', 'FABP4']
# [[  4802.  15162. 252502.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[  4802.  15162. 252502.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[  4802.  15162. 252502.]]
# Final (12374, 31881)
# ******************* Sims_2019 36/38
# Matrix: (10790, 60725) 2023-02-07 21:55:49
# Repeated features 6312 => 2232
# ['SPP1', 'TREM2', 'FABP4']
# [[2. 0. 0.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[2. 0. 0.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[2. 0. 0.]]
# Final (10790, 56645)
# ******************* Schultze_unpubl 37/38
# Matrix: (8016, 24532) 2023-02-07 21:55:51
# Repeated features 542 => 252
# ['SPP1', 'TREM2', 'FABP4']
# [[  116.   431. 13699.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[  116.   431. 13699.]]
# ['SPP1', 'TREM2', 'FABP4']
# [[  116.   431. 13699.]]
# Final (8016, 24242)
# CPU times: user 5min 20s, sys: 1min 26s, total: 6min 46s
# Wall time: 6min 47s

# %%
ephi = set(
    list(
        itertools.chain.from_iterable(
            [feature_conversion[ds]["original"] for ds in feature_conversion.keys()]
        )
    )
)
temp = set(
    list(
        itertools.chain.from_iterable(
            [query_adatas[ds].var_names for ds in query_adatas.keys()]
        )
    )
)
tvar = set(
    list(
        itertools.chain.from_iterable(
            [feature_conversion[ds]["new"] for ds in feature_conversion.keys()]
        )
    )
)
print(f"Before harmonization: total genes: {len(ephi)}")
print(f"After harmonization: total theoretical genes: {len(tvar)}")
print(f"After harmonization: total object genes: {len(temp)}")
# Out:
# Before harmonization: total genes: 94538
# After harmonization: total theoretical genes: 59574
# After harmonization: total object genes: 59574

# %%
if temp != tvar:
    for ds in feature_conversion.keys():
        var_diff = list(
            set(feature_conversion[ds]["new"]) - set(query_adatas[ds].var_names)
        )
        if len(var_diff) > 0:
            print(f"{ds} ({len(var_diff)}):\n", var_diff[:3], "\n", var_diff[-3:])

# %%
del adatas

# %%
gc.collect()
# Out:
# 36101

# %% [markdown]
# Finally the concatenation!

# %%
# %%time
adata_o = sc.AnnData.concatenate(
    *query_adatas.values(),
    join="outer",
    batch_key=None,
    batch_categories=list(query_adatas.keys()),
    index_unique="_"
)
# Out:
# CPU times: user 1min 15s, sys: 18.8 s, total: 1min 33s
# Wall time: 1min 34s

# %%
adata_o
# Out:
# AnnData object with n_obs × n_vars = 2500001 × 59574
#     obs: 'cellname', 'study'

# %% [markdown]
# Now checking overlap of obs with the embedding object so we can add the matadata.

# %%
temp = "_HLCA$"  # |carraro_cff_|carraro_csmc_|carraro_ucla_|sub_wang_sub_batch3_|sub_wang_sub_batch4_|sub_wang_sub_batch1_|sub_wang_sub_batch2_|delorey_fresh_|delorey_cryo_|delorey_nuclei_|grant_fresh_|grant_cryo_"
adata_o.obs_names = [re.sub(temp, "", i) for i in adata_o.obs_names]

# %%
print("Total merged:", len(adata_o.obs_names))
print("Total in Embedding:", embed_obs.shape[0])
print(
    "Concatenation overlap with old Embedding names:",
    len(adata_o.obs_names.intersection(df_cellnames["old"])),
)
print(
    "Concatenation overlap with new names:",
    len(adata_o.obs_names.intersection(df_cellnames["new"])),
)
# Out:
# Total merged: 2500001
# Total in Embedding: 2382658
# Concatenation overlap with old Embedding names: 0
# Concatenation overlap with new names: 2382658

# %% [markdown]
# <b style='color:red;'>We want to recover all cells in the embedding</b>

# %% [markdown]
# Check missmatching barcodes

# %%
temp = list(set(df_cellnames["new"]) - set(adata_o.obs_names))
df_cellnames_missed = df_cellnames.loc[df_cellnames.new.isin(temp), :]
cellnames_missed = df_cellnames_missed["study"].value_counts()
cellnames_missed = cellnames_missed[cellnames_missed > 0]
cellnames_missed
# Out:
# Series([], Name: study, dtype: int64)

# %%
df_cellnames["study"].value_counts()[cellnames_missed.index]
# Out:
# Series([], Name: study, dtype: int64)

# %%
print("Total:")
df = embed_obs.loc[embed_obs["study"].isin(cellnames_missed.index), :]
pd.crosstab(df["dataset_temp"], df["study"])
print("Missing:")
df = embed_obs.loc[df_cellnames_missed.index, :]
pd.crosstab(df["dataset_temp"], df["study"])
# Out:
# Total:
# Missing:
# Empty DataFrame
# Columns: []
# Index: []

# %%
adata_o.obs["study"].value_counts()[cellnames_missed.index]
# Out:
# Series([], Name: study, dtype: int64)

# %%
temp = cellnames_missed.index
show_examples = len(temp) == 0
if show_examples:
    temp = list(set(df_cellnames.study))[:3]
for ds in temp:
    print(f"\033[1m\033[94m*******************\033[0m {ds}")
    ds_clean = re.sub("_HLCA$", "", ds)
    df = df_cellnames.loc[df_cellnames.study.isin([ds_clean]), :]
    df = df.loc[
        ~df["new"].isin(adata_o.obs_names),
    ].iloc[:3, :]
    if not show_examples:
        try:
            flag = "(old)"
            temp = embed_obs.loc[df["old"], :]
        except KeyError:
            flag = "(isin)"
            temp = embed_obs.loc[embed_obs.study.isin([ds]), :]
        print(f"Embedding {flag}")
        temp
    if df.shape[0] > 0:
        print("Conversion")
        df
    df_adata_o = adata_o.obs.loc[adata_o.obs.study.isin([ds]), :]
    # df_adata_o = df_adata_o.loc[
    #     list(set(df_adata_o.index) - set(df_cellnames["new"])),
    # ]
    try:
        flag = "(old)"
        temp = df_adata_o.loc[df["old"], :]
    except KeyError:
        try:
            flag = "(new)"
            temp = df_adata_o.loc[df["new"], :]
        except KeyError:
            flag = "(isin)"
            temp = df_adata_o.iloc[:3, :]
    if temp.shape[0] > 0:
        print(f"Concatenated {flag}")
        temp
# Out:
# ******************* Zhang_2021
# ******************* Lafyatis_Rojas_2019
# ******************* Banovich_Kropski_2020

# %%
if not show_examples:
    bcode = "AAACCTGCAAAGGTGC"
    matching = [s for s in adata_o.obs_names if bcode in s]
    adata_o.obs.loc[matching, :]
    matching = [s for s in df_cellnames.index if bcode in s]
    df_cellnames.loc[matching, :]

# %% [markdown]
# Renaming barcodes and adding metadata

# %%
adata_o.obs
# Out:
#                                                           cellname  \
# ACCCACTGAACTGC-SC14_Lafyatis_Rojas_2019        ACCCACTGAACTGC-SC14
# GACCAATGTGCTCTTC-SC156_Lafyatis_Rojas_2019  GACCAATGTGCTCTTC-SC156
# CTGATCCTCGTGGGAA-SC45_Lafyatis_Rojas_2019    CTGATCCTCGTGGGAA-SC45
# GCCAAATCAAAGGCGT-SC56_Lafyatis_Rojas_2019    GCCAAATCAAAGGCGT-SC56
# TACGCCACGATGAA-SC14_Lafyatis_Rojas_2019        TACGCCACGATGAA-SC14
# ...                                                            ...
# Pool_426_TTTGTCTAAGCA_Schultze_unpubl        Pool_426_TTTGTCTAAGCA
# Pool_426_TTTTCGCGGTCA_Schultze_unpubl        Pool_426_TTTTCGCGGTCA
# Pool_426_TTTTCTACGCCT_Schultze_unpubl        Pool_426_TTTTCTACGCCT
# Pool_426_TTTTCTAGCCCC_Schultze_unpubl        Pool_426_TTTTCTAGCCCC
# Pool_426_TTTTTGGAACAG_Schultze_unpubl        Pool_426_TTTTTGGAACAG
#
#                                                                study
# ACCCACTGAACTGC-SC14_Lafyatis_Rojas_2019     Lafyatis_Rojas_2019_HLCA
# GACCAATGTGCTCTTC-SC156_Lafyatis_Rojas_2019  Lafyatis_Rojas_2019_HLCA
# CTGATCCTCGTGGGAA-SC45_Lafyatis_Rojas_2019   Lafyatis_Rojas_2019_HLCA
# GCCAAATCAAAGGCGT-SC56_Lafyatis_Rojas_2019   Lafyatis_Rojas_2019_HLCA
# TACGCCACGATGAA-SC14_Lafyatis_Rojas_2019     Lafyatis_Rojas_2019_HLCA
# ...                                                              ...
# Pool_426_TTTGTCTAAGCA_Schultze_unpubl                Schultze_unpubl
# Pool_426_TTTTCGCGGTCA_Schultze_unpubl                Schultze_unpubl
# Pool_426_TTTTCTACGCCT_Schultze_unpubl                Schultze_unpubl
# Pool_426_TTTTCTAGCCCC_Schultze_unpubl                Schultze_unpubl
# Pool_426_TTTTTGGAACAG_Schultze_unpubl                Schultze_unpubl
#
# [2500001 rows x 2 columns]

# %%
df_cellnames_order = df_cellnames.loc[
    [i in adata_o.obs_names for i in df_cellnames["new"]], :
]

# %%
df_cellnames_order
# Out:
#                                                                                                  old  \
# AAACCCACAGCTACAT_3_liao                                                      AAACCCACAGCTACAT_3_liao
# AAACCCATCCACGGGT_3_liao                                                      AAACCCATCCACGGGT_3_liao
# AAACGAACAAACAGGC_3_liao                                                      AAACGAACAAACAGGC_3_liao
# AAACGAAGTCGCACAC_3_liao                                                      AAACGAAGTCGCACAC_3_liao
# AAACGAAGTGTAGTGG_3_liao                                                      AAACGAAGTGTAGTGG_3_liao
# ...                                                                                              ...
# TTTGTCAGTACCATCA-1-WTDAtest7732270-0_meyer_unpubl  TTTGTCAGTACCATCA-1-WTDAtest7732270-0_meyer_unpubl
# TTTGTCAGTAGCCTCG-1-WTDAtest7732270-0_meyer_unpubl  TTTGTCAGTAGCCTCG-1-WTDAtest7732270-0_meyer_unpubl
# TTTGTCAGTTAAGACA-1-WTDAtest7732270-0_meyer_unpubl  TTTGTCAGTTAAGACA-1-WTDAtest7732270-0_meyer_unpubl
# TTTGTCATCACCATAG-1-WTDAtest7732270-0_meyer_unpubl  TTTGTCATCACCATAG-1-WTDAtest7732270-0_meyer_unpubl
# TTTGTCATCCAACCAA-1-WTDAtest7732270-0_meyer_unpubl  TTTGTCATCCAACCAA-1-WTDAtest7732270-0_meyer_unpubl
#
#                                                                                                new  \
# AAACCCACAGCTACAT_3_liao                                              AAACCCACAGCTACAT_3_Zhang_2021
# AAACCCATCCACGGGT_3_liao                                              AAACCCATCCACGGGT_3_Zhang_2021
# AAACGAACAAACAGGC_3_liao                                              AAACGAACAAACAGGC_3_Zhang_2021
# AAACGAAGTCGCACAC_3_liao                                              AAACGAAGTCGCACAC_3_Zhang_2021
# AAACGAAGTGTAGTGG_3_liao                                              AAACGAAGTGTAGTGG_3_Zhang_2021
# ...                                                                                            ...
# TTTGTCAGTACCATCA-1-WTDAtest7732270-0_meyer_unpubl  TTTGTCAGTACCATCA-1-WTDAtest7732270-0_Meyer_2021
# TTTGTCAGTAGCCTCG-1-WTDAtest7732270-0_meyer_unpubl  TTTGTCAGTAGCCTCG-1-WTDAtest7732270-0_Meyer_2021
# TTTGTCAGTTAAGACA-1-WTDAtest7732270-0_meyer_unpubl  TTTGTCAGTTAAGACA-1-WTDAtest7732270-0_Meyer_2021
# TTTGTCATCACCATAG-1-WTDAtest7732270-0_meyer_unpubl  TTTGTCATCACCATAG-1-WTDAtest7732270-0_Meyer_2021
# TTTGTCATCCAACCAA-1-WTDAtest7732270-0_meyer_unpubl  TTTGTCATCCAACCAA-1-WTDAtest7732270-0_Meyer_2021
#
#                                                         study
# AAACCCACAGCTACAT_3_liao                            Zhang_2021
# AAACCCATCCACGGGT_3_liao                            Zhang_2021
# AAACGAACAAACAGGC_3_liao                            Zhang_2021
# AAACGAAGTCGCACAC_3_liao                            Zhang_2021
# AAACGAAGTGTAGTGG_3_liao                            Zhang_2021
# ...                                                       ...
# TTTGTCAGTACCATCA-1-WTDAtest7732270-0_meyer_unpubl  Meyer_2021
# TTTGTCAGTAGCCTCG-1-WTDAtest7732270-0_meyer_unpubl  Meyer_2021
# TTTGTCAGTTAAGACA-1-WTDAtest7732270-0_meyer_unpubl  Meyer_2021
# TTTGTCATCACCATAG-1-WTDAtest7732270-0_meyer_unpubl  Meyer_2021
# TTTGTCATCCAACCAA-1-WTDAtest7732270-0_meyer_unpubl  Meyer_2021
#
# [2382658 rows x 3 columns]

# %%
adata_o = adata_o[df_cellnames_order["new"], :]

# %%
del query_adatas
gc.collect()
# Out:
# 4847

# %%
adata_o_obs = adata_o.obs.copy()
adata_o_obs
# Out:
#                                                                              cellname  \
# AAACCCACAGCTACAT_3_Zhang_2021                                      AAACCCACAGCTACAT_3
# AAACCCATCCACGGGT_3_Zhang_2021                                      AAACCCATCCACGGGT_3
# AAACGAACAAACAGGC_3_Zhang_2021                                      AAACGAACAAACAGGC_3
# AAACGAAGTCGCACAC_3_Zhang_2021                                      AAACGAAGTCGCACAC_3
# AAACGAAGTGTAGTGG_3_Zhang_2021                                      AAACGAAGTGTAGTGG_3
# ...                                                                               ...
# TTTGTCAGTACCATCA-1-WTDAtest7732270-0_Meyer_2021  TTTGTCAGTACCATCA-1-WTDAtest7732270-0
# TTTGTCAGTAGCCTCG-1-WTDAtest7732270-0_Meyer_2021  TTTGTCAGTAGCCTCG-1-WTDAtest7732270-0
# TTTGTCAGTTAAGACA-1-WTDAtest7732270-0_Meyer_2021  TTTGTCAGTTAAGACA-1-WTDAtest7732270-0
# TTTGTCATCACCATAG-1-WTDAtest7732270-0_Meyer_2021  TTTGTCATCACCATAG-1-WTDAtest7732270-0
# TTTGTCATCCAACCAA-1-WTDAtest7732270-0_Meyer_2021  TTTGTCATCCAACCAA-1-WTDAtest7732270-0
#
#                                                       study
# AAACCCACAGCTACAT_3_Zhang_2021                    Zhang_2021
# AAACCCATCCACGGGT_3_Zhang_2021                    Zhang_2021
# AAACGAACAAACAGGC_3_Zhang_2021                    Zhang_2021
# AAACGAAGTCGCACAC_3_Zhang_2021                    Zhang_2021
# AAACGAAGTGTAGTGG_3_Zhang_2021                    Zhang_2021
# ...                                                     ...
# TTTGTCAGTACCATCA-1-WTDAtest7732270-0_Meyer_2021  Meyer_2021
# TTTGTCAGTAGCCTCG-1-WTDAtest7732270-0_Meyer_2021  Meyer_2021
# TTTGTCAGTTAAGACA-1-WTDAtest7732270-0_Meyer_2021  Meyer_2021
# TTTGTCATCACCATAG-1-WTDAtest7732270-0_Meyer_2021  Meyer_2021
# TTTGTCATCCAACCAA-1-WTDAtest7732270-0_Meyer_2021  Meyer_2021
#
# [2382658 rows x 2 columns]

# %%
# %%time
adata_o.obs = embed_obs.loc[df_cellnames_order["old"], :].copy()
# Out:
# CPU times: user 34.3 s, sys: 22.6 s, total: 56.9 s
# Wall time: 57.1 s

# %% [markdown]
# Some datasets have the same name even though one is in the core and the other in the extension. Might be a problem but essentially they can belong to the same dataset, just with a different purpose.

# %%
df = adata_o.obs.study.value_counts().reset_index()
temp = df_cellnames.study.value_counts()[[re.sub("_HLCA", "", i) for i in df["index"]]]
df["index_all"] = temp.index
df["study_all"] = temp.tolist()
df.sort_values(by=["study", "index"], ascending=False)
# Out:
#                      index   study               index_all  study_all
# 0            Kaminski_2020  307650           Kaminski_2020     307650
# 1    Banovich_Kropski_2020  204586   Banovich_Kropski_2020     204586
# 2               Meyer_2021  129340              Meyer_2021     129340
# 3       Meyer_Nikolic_2022  119634      Meyer_Nikolic_2022     119634
# 4            Barbry_unpubl  100211           Barbry_unpubl     100211
# 5               Regev_2021   96060              Regev_2021      96060
# 6           Thienpont_2018   93575          Thienpont_2018      93575
# 7            Budinger_2020   91980           Budinger_2020      91980
# 8            Sheppard_2020   80020           Sheppard_2020      80020
# 9   Misharin_Budinger_2018   78317  Misharin_Budinger_2018      78317
# 10          Wunderink_2021   77146          Wunderink_2021      77146
# 11       Barbry_Leroy_2020   74487       Barbry_Leroy_2020      74487
# 12             Nawijn_2021   70402             Nawijn_2021      70402
# 13         Lambrechts_2021   65166         Lambrechts_2021      65166
# 14           Misharin_2021   64843           Misharin_2021      64843
# 15              Zhang_2021   62469              Zhang_2021      62469
# 16            Krasnow_2020   60982            Krasnow_2020      60982
# 17    Duong_lungMAP_unpubl   53904    Duong_lungMAP_unpubl      53904
# 18            Janssen_2020   49384            Janssen_2020      49384
# 19                Sun_2020   46500                Sun_2020      46500
# 20      Jain_Misharin_2021   45557      Jain_Misharin_2021      45557
# 21           Gomperts_2021   40709           Gomperts_2021      40709
# 22               Eils_2020   39778               Eils_2020      39778
# 23           Schiller_2020   38648           Schiller_2020      38648
# 24             Shalek_2018   36740             Shalek_2018      36740
# 25           Schiller_2021   35984           Schiller_2021      35984
# 26              Meyer_2019   35554              Meyer_2019      35554
# 27            Seibold_2020   33593            Seibold_2020      33593
# 28      Peer_Massague_2020   32850      Peer_Massague_2020      32850
# 29           Lafyatis_2019   27297           Lafyatis_2019      27297
# 30     Lafyatis_Rojas_2019   24181     Lafyatis_Rojas_2019      24181
# 31             Tata_unpubl   21700             Tata_unpubl      21700
# 32                 Xu_2020   12374                 Xu_2020      12374
# 33    Teichmann_Meyer_2019   12231    Teichmann_Meyer_2019      12231
# 34               Sims_2019   10790               Sims_2019      10790
# 35         Schultze_unpubl    8016         Schultze_unpubl       8016

# %% [markdown]
# We are adding a pair of column with "harmonised" cell names and the cell names we have so far.

# %%
adata_o.obs["cellname_original"] = adata_o_obs.loc[
    df_cellnames_order["new"], "cellname"
].tolist()
# adata_o.obs["cellname"] = df_cellnames_order["old"].tolist()
# adata_o.obs["cellname_harmonised"] = df_cellnames_order["new"].tolist()

# %% [markdown]
# ### Conclusions <a class="anchor" id="bullet5"></a>

# %%
adata_o
# Out:
# AnnData object with n_obs × n_vars = 2382658 × 59574
#     obs: 'sample', 'original_celltype_ann', 'study_long', 'study', 'last_author_PI', 'subject_ID', 'subject_ID_as_published', 'pre_or_postnatal', 'age_in_years', 'age_range', 'sex', 'smoking_status', 'smoking_history', 'BMI', 'known_lung_disease', 'condition', 'subject_type', 'cause_of_death', 'sample_type', 'anatomical_region_coarse', 'anatomical_region_detailed', 'tissue_dissociation_protocol', 'cells_or_nuclei', 'single_cell_platform', "3'_or_5'", 'enrichment', 'sequencing_platform', 'reference_genome_coarse', 'ensembl_release_reference_genome', 'cell_ranger_version', 'disease_status', 'fresh_or_frozen', 'cultured', 'cell_viability_%', 'comments', 'Processing_site', 'dataset', 'anatomical_region_level_1', 'anatomical_region_level_2', 'anatomical_region_level_3', 'anatomical_region_highest_res', 'age', 'ann_level_1', 'ann_level_2', 'ann_level_3', 'ann_level_4', 'ann_level_5', 'ann_highest_res', 'ann_new', 'n_genes', 'total_counts', 'log10_total_counts', 'n_genes_detected', 'mito_frac', 'ribo_frac', 'compl', 'size_factors', 'ann_level_1_clean', 'ann_level_2_clean', 'ann_level_3_clean', 'ann_level_4_clean', 'ann_level_5_clean', 'scanvi_label', 'leiden_1', 'leiden_2', 'leiden_3', 'anatomical_region_ccf_score', 'manual_ann', 'leiden_4', 'reannotation_type', 'leiden_5', 'original_ann_level_1', 'original_ann_level_2', 'original_ann_level_3', 'original_ann_level_4', 'original_ann_level_5', 'original_ann_highest_res', 'original_ann_new', 'original_ann_level_1_clean', 'original_ann_level_2_clean', 'original_ann_level_3_clean', 'original_ann_level_4_clean', 'original_ann_level_5_clean', 'cluster_annotated', 'manual_ann_grouped', 'entropy_subject_ID_leiden_3', 'entropy_dataset_leiden_3', 'entropy_original_ann_level_1_leiden_3', 'entropy_original_ann_level_2_clean_leiden_3', 'entropy_original_ann_level_3_clean_leiden_3', 'core_or_extension', 'ancestry', 'mixed_ancestry', 'transf_ann_level_1_label', 'transf_ann_level_1_uncert', 'transf_ann_level_2_label', 'transf_ann_level_2_uncert', 'transf_ann_level_3_label', 'transf_ann_level_3_uncert', 'transf_ann_level_4_label', 'transf_ann_level_4_uncert', 'transf_ann_level_5_label', 'transf_ann_level_5_uncert', 'study_coe', 'dataset_temp', 'cellname_original'

# %%
del adata_o.obs["study_coe"]
del adata_o.obs["dataset_temp"]

# %% [markdown]
# ### Save <a class="anchor" id="bullet6"></a>

# %%
# %%time
adata_o.write(filename=adata_o_out)
# Out:
# CPU times: user 36 s, sys: 56.9 s, total: 1min 32s
# Wall time: 1min 39s

# %% [markdown]
# Done.
